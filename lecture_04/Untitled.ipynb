# %% [markdown]
# # Anwendungsbeispiel: Nachrichten-Crawler

# %%
import requests 
import lxml.html as lh
from urllib.parse import urljoin

base = 'https://deutschlan'
visited = set()
ignored = set()
todo = { base }

while len(todo) > 0:
    print(f"URLs to crawl: {len(todo)}")
    url = todo.pop()
    print(f"crawling {url}")
    visited.add(url)
    
    resp = requests.get(url)
    if not resp:
        continue
        
    # url könnte aufgrund redirect verändert sein
    url = resp.url
    visited.add(url)
    doc = lh.fromstring(resp.content)
    for link in doc.xpath('//a'):
        href = link.get('href')
        # URLs außerhalb der FH nicht folgen
        if href is None or len(href) == 0:
            continue
            
        # Löse Link URL auf    
        href = urljoin(url, href)
        
        if not href.startswith(base):
            # print(f"ignoring: {href}")
            ignored.add(href)
            continue
        
        if not href in visited:
            todo.add(href)
        
print(f"{len(visited)} pages crawled, {len(ignored)} links ignored")
# Out:
# URLs to crawl: 1
# crawling https://github.com/fhswf
# URLs to crawl: 12
# crawling https://github.com/fhswf/latex-ifv/issues
# URLs to crawl: 22
# crawling https://github.com/fhswf/latex-ifv/labels
# URLs to crawl: 35
# crawling https://github.com/fhswf#start-of-content
# URLs to crawl: 34
# crawling https://github.com/fhswf/latex-ifv/projects
# URLs to crawl: 34
# crawling https://github.com/fhswf/latex-ifv
# URLs to crawl: 50
# crawling https://github.com/fhswf/skriptsprachen/pulls
# URLs to crawl: 59
# crawling https://github.com/fhswf/latex-ifv#installation-unter-debian-9
# URLs to crawl: 58
# crawling https://github.com/fhswf/latex-ifv/pulse
# URLs to crawl: 65
# crawling https://github.com/fhswf/skriptsprachen/pulls#start-of-content
# URLs to crawl: 64
# crawling https://github.com/fhswf/latex-ifv/milestones
# URLs to crawl: 74
# crawling https://github.com/fhswf/latex-ifv/network/members
# URLs to crawl: 74
# crawling https://github.com/fhswf/latex-ifv/labels?sort=count-desc
# URLs to crawl: 74
# crawling https://github.com/fhswf/skriptsprachen/network/members
# URLs to crawl: 79
# crawling https://github.com/fhswf/latex-ifv/milestones?state=open
# URLs to crawl: 79
# crawling https://github.com/fhswf/skriptsprachen/pulse
# URLs to crawl: 82
# crawling https://github.com/fhswf/skriptsprachen/graphs/code-frequency
# URLs to crawl: 82
# crawling https://github.com/fhswf/latex-ifv/labels/good%20first%20issue
# URLs to crawl: 83
# crawling https://github.com/fhswf/skriptsprachen/security/advisories
# URLs to crawl: 85
# crawling https://github.com/fhswf/skriptsprachen/issues?q=is%3Apr+is%3Aopen+base%3Amaster
# URLs to crawl: 87
# crawling https://github.com/fhswf/latex-ifv/pulse#start-of-content
# URLs to crawl: 86
# crawling https://github.com/fhswf/latex-ifv/pulse/monthly
# URLs to crawl: 86
# crawling https://github.com/fhswf/latex-ifv/blob/master/README.md
# URLs to crawl: 92
# crawling https://github.com/fhswf/latex-ifv/search?l=tex
# URLs to crawl: 109
# crawling https://github.com/fhswf/latex-ifv/search?l=tex&type=Wikis
# URLs to crawl: 109
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=desc&sort=title&state=open
# URLs to crawl: 109
# crawling https://github.com/fhswf/latex-ifv/branches
# URLs to crawl: 112
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=desc&sort=completeness&state=open
# URLs to crawl: 112
# crawling https://github.com/fhswf/latex-ifv/labels/bug
# URLs to crawl: 113
# crawling https://github.com/fhswf/latex-ifv/milestones?state=open#start-of-content
# URLs to crawl: 112
# crawling https://github.com/fhswf/latex-ifv/pulse/daily
# URLs to crawl: 112
# crawling https://github.com/fhswf/latex-ifv/search?l=YAML
# URLs to crawl: 119
# crawling https://github.com/fhswf/latex-ifv/pulls
# URLs to crawl: 121
# crawling https://github.com/fhswf/image_captioning/issues
# URLs to crawl: 144
# crawling https://github.com/fhswf/latex-ifv/labels/help%20wanted
# URLs to crawl: 145
# crawling https://github.com/fhswf/latex-ifv/milestones#start-of-content
# URLs to crawl: 144
# crawling https://github.com/fhswf/latex-ifv/labels?sort=count-desc#start-of-content
# URLs to crawl: 143
# crawling https://github.com/fhswf/image_captioning/security/advisories
# URLs to crawl: 145
# crawling https://github.com/fhswf/skriptsprachen/security/advisories#start-of-content
# URLs to crawl: 144
# crawling https://github.com/fhswf/latex-ifv/blob/master/README.md#installation-unter-opensuse-leap-423
# URLs to crawl: 143
# crawling https://github.com/fhswf/latex-ifv/search?l=YAML&type=Issues
# URLs to crawl: 143
# crawling https://github.com/fhswf/skriptsprachen/network/dependencies
# URLs to crawl: 144
# crawling https://github.com/fhswf/latex-ifv/labels#start-of-content
# URLs to crawl: 143
# crawling https://github.com/fhswf/latex-ifv/security/advisories
# URLs to crawl: 145
# crawling https://github.com/fhswf/image_captioning/watchers
# URLs to crawl: 145
# crawling https://github.com/fhswf/skriptsprachen/graphs/commit-activity
# URLs to crawl: 145
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=desc&sort=count&state=open
# URLs to crawl: 145
# crawling https://github.com/fhswf/image_captioning/security/policy
# URLs to crawl: 145
# crawling https://github.com/fhswf/latex-ifv/blob/master/.gitlab-ci.yml
# URLs to crawl: 149
# crawling https://github.com/fhswf/latex-ifv/search?l=Markdown
# URLs to crawl: 154
# crawling https://github.com/fhswf/skriptsprachen/stargazers
# URLs to crawl: 155
# crawling https://github.com/fhswf/latex-ifv/branches#start-of-content
# URLs to crawl: 154
# crawling https://github.com/fhswf/skriptsprachen/pulse/daily
# URLs to crawl: 154
# crawling https://github.com/fhswf/latex-ifv/search?l=YAML&type=Code
# URLs to crawl: 154
# crawling https://github.com/fhswf/image_captioning
# URLs to crawl: 194
# crawling https://github.com/fhswf/skriptsprachen/graphs/commit-activity#start-of-content
# URLs to crawl: 193
# crawling https://github.com/fhswf/image_captioning#run
# URLs to crawl: 192
# crawling https://github.com/fhswf/latex-ifv/raw/master/.gitlab-ci.yml
# URLs to crawl: 191
# crawling https://github.com/fhswf/image_captioning/issues#start-of-content
# URLs to crawl: 191
# crawling https://github.com/fhswf/latex-ifv/blob/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/README.md
# URLs to crawl: 197
# crawling https://github.com/fhswf/latex-ifv/labels/duplicate
# URLs to crawl: 198
# crawling https://github.com/fhswf/latex-ifv/search?l=tex&type=Wikis#start-of-content
# URLs to crawl: 197
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=desc&sort=title&state=open#start-of-content
# URLs to crawl: 196
# crawling https://github.com/fhswf/latex-ifv/labels/bug#start-of-content
# URLs to crawl: 196
# crawling https://github.com/fhswf/latex-ifv/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50
# URLs to crawl: 196
# crawling https://github.com/fhswf/latex-ifv/search?l=YAML#start-of-content
# URLs to crawl: 195
# crawling https://github.com/fhswf/latex-ifv/labels?sort=name-asc
# URLs to crawl: 195
# crawling https://github.com/fhswf/latex-ifv/search?l=TeX
# URLs to crawl: 200
# crawling https://github.com/fhswf/latex-ifv/labels/wontfix
# URLs to crawl: 201
# crawling https://github.com/fhswf/latex-ifv/labels/question
# URLs to crawl: 201
# crawling https://github.com/fhswf/latex-ifv/blob/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/kapitel1.tex
# URLs to crawl: 205
# crawling https://github.com/fhswf/skriptsprachen/security/advisories?state=published
# URLs to crawl: 205
# crawling https://github.com/fhswf/skriptsprachen/watchers
# URLs to crawl: 205
# crawling https://github.com/fhswf/latex-ifv/issues/new
# URLs to crawl: 204
# crawling https://github.com/fhswf/latex-ifv/network/dependencies
# URLs to crawl: 205
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Areactions-tada-desc
# URLs to crawl: 210
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Areactions-heart-desc
# URLs to crawl: 213
# crawling https://github.com/fhswf/latex-ifv/search?l=Markdown&type=Code
# URLs to crawl: 213
# crawling https://github.com/fhswf/image_captioning/blob/master/evaluation.py
# URLs to crawl: 219
# crawling https://github.com/fhswf/latex-ifv/raw/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/kapitel1.tex
# URLs to crawl: 218
# crawling https://github.com/fhswf/latex-ifv/branches/all
# URLs to crawl: 218
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Aupdated-desc
# URLs to crawl: 220
# crawling https://github.com/fhswf/latex-ifv/network/dependencies#start-of-content
# URLs to crawl: 219
# crawling https://github.com/fhswf/latex-ifv/find/master
# URLs to crawl: 220
# crawling https://github.com/fhswf/skriptsprachen/labels
# URLs to crawl: 233
# crawling https://github.com/fhswf/latex-ifv/labels/help%20wanted#start-of-content
# URLs to crawl: 233
# crawling https://github.com/fhswf/skriptsprachen/graphs/code-frequency#start-of-content
# URLs to crawl: 232
# crawling https://github.com/fhswf/image_captioning/pulse
# URLs to crawl: 239
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Areactions-smile-desc
# URLs to crawl: 241
# crawling https://github.com/fhswf/latex-ifv/blob/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/README.md#installation-unter-opensuse-leap-423
# URLs to crawl: 240
# crawling https://github.com/fhswf/image_captioning/releases
# URLs to crawl: 241
# crawling https://github.com/fhswf/skriptsprachen/network
# URLs to crawl: 241
# crawling https://github.com/fhswf/image_captioning#changes-from-the-original-project-by-trang-nguyen
# URLs to crawl: 240
# crawling https://github.com/fhswf/image_captioning/graphs/code-frequency
# URLs to crawl: 240
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=asc&sort=count&state=open
# URLs to crawl: 240
# crawling https://github.com/fhswf/image_captioning/security/advisories?state=published
# URLs to crawl: 240
# crawling https://github.com/fhswf/image_captioning/blob/master/utils.py
# URLs to crawl: 245
# crawling https://github.com/fhswf/skriptsprachen/stargazers#start-of-content
# URLs to crawl: 244
# crawling https://github.com/fhswf/image_captioning/graphs/contributors
# URLs to crawl: 244
# crawling https://github.com/fhswf/latex-ifv/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50#start-of-content
# URLs to crawl: 243
# crawling https://github.com/fhswf/image_captioning/commits/master/utils.py
# URLs to crawl: 257
# crawling https://github.com/fhswf/latex-ifv/search?l=tex&type=RegistryPackages
# URLs to crawl: 257
# crawling https://github.com/fhswf/latex-ifv/blob/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/README.md#start-of-content
# URLs to crawl: 256
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Areactions-smile-desc#start-of-content
# URLs to crawl: 255
# crawling https://github.com/fhswf/latex-ifv/issues?q=is%3Apr+is%3Aopen+updated%3A%3C2019-09-20
# URLs to crawl: 256
# crawling https://github.com/fhswf/latex-ifv/projects#start-of-content
# URLs to crawl: 255
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Areactions-tada-desc+comments%3A%3E50
# URLs to crawl: 272
# crawling https://github.com/fhswf/image_captioning/pulse/halfweekly
# URLs to crawl: 272
# crawling https://github.com/fhswf/image_captioning/blame/master/utils.py
# URLs to crawl: 283
# crawling https://github.com/fhswf/skriptsprachen/labels/good%20first%20issue
# URLs to crawl: 285
# crawling https://github.com/fhswf/skriptsprachen/network/dependents
# URLs to crawl: 287
# crawling https://github.com/fhswf/image_captioning/projects
# URLs to crawl: 287
# crawling https://github.com/fhswf/latex-ifv/search?l=BibTeX
# URLs to crawl: 293
# crawling https://github.com/fhswf/image_captioning/pulls
# URLs to crawl: 312
# crawling https://github.com/fhswf/latex-ifv/search?l=Markdown&type=Code#start-of-content
# URLs to crawl: 311
# crawling https://github.com/fhswf/image_captioning/blob/master/.gitignore
# URLs to crawl: 316
# crawling https://github.com/fhswf/latex-ifv/security/policy
# URLs to crawl: 316
# crawling https://github.com/fhswf/latex-ifv/commits/master/README.md
# URLs to crawl: 321
# crawling https://github.com/fhswf/image_captioning/blob/master/1_Preliminaries.ipynb
# URLs to crawl: 326
# crawling https://github.com/fhswf/skriptsprachen/labels/wontfix
# URLs to crawl: 327
# crawling https://github.com/fhswf/latex-ifv/blob/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/ifv.sty
# URLs to crawl: 330
# crawling https://github.com/fhswf/latex-ifv/network/members#start-of-content
# URLs to crawl: 329
# crawling https://github.com/fhswf/image_captioning/blame/master/evaluation.py
# URLs to crawl: 342
# crawling https://github.com/fhswf/image_captioning/tree/5cded40661b31af3f63a86124fc9086af365f088
# URLs to crawl: 363
# crawling https://github.com/fhswf/latex-ifv/network/dependents
# URLs to crawl: 365
# crawling https://github.com/fhswf/latex-ifv/search?l=YAML&type=Issues#start-of-content
# URLs to crawl: 364
# crawling https://github.com/fhswf/image_captioning/blame/b9d41fc830cf7fc3844465c03a56fda3676bf2a3/evaluation.py
# URLs to crawl: 368
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+sort%3Acreated-desc
# URLs to crawl: 371
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+sort%3Aupdated-desc
# URLs to crawl: 380
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+comments%3A%3E50+sort%3Acreated-desc+is%3Aclosed
# URLs to crawl: 395
# crawling https://github.com/fhswf/latex-ifv/labels?sort=name-desc
# URLs to crawl: 395
# crawling https://github.com/fhswf/latex-ifv/search?l=Markdown&type=Issues
# URLs to crawl: 395
# crawling https://github.com/fhswf/skriptsprachen/issues?q=is%3Apr+is%3Aopen+base%3Amaster+no%3Amilestone
# URLs to crawl: 396
# crawling https://github.com/fhswf/latex-ifv/labels/invalid
# URLs to crawl: 397
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=asc&sort=completeness&state=open
# URLs to crawl: 397
# crawling https://github.com/fhswf/latex-ifv/pulse/halfweekly
# URLs to crawl: 397
# crawling https://github.com/fhswf/latex-ifv/search?l=Markdown&type=Wikis
# URLs to crawl: 397
# crawling https://github.com/fhswf/latex-ifv/blob/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/include/trennungen.tex
# URLs to crawl: 401
# crawling https://github.com/fhswf/skriptsprachen/issues?q=is%3Aissue+is%3Aopen
# URLs to crawl: 402
# crawling https://github.com/fhswf/image_captioning/commits/master/1_Preliminaries.ipynb
# URLs to crawl: 404
# crawling https://github.com/fhswf/skriptsprachen/graphs/contributors
# URLs to crawl: 404
# crawling https://github.com/fhswf/latex-ifv/milestones?state=closed
# URLs to crawl: 412
# crawling https://github.com/fhswf/latex-ifv/raw/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/README.md
# URLs to crawl: 411
# crawling https://github.com/fhswf/latex-ifv/labels?sort=name-asc#start-of-content
# URLs to crawl: 410
# crawling https://github.com/fhswf/image_captioning/network/dependencies
# URLs to crawl: 411
# crawling https://github.com/fhswf/image_captioning/commit/3d7b9f61401a7a21be1af7a181a353083a10e213
# URLs to crawl: 417
# crawling https://github.com/fhswf/skriptsprachen/issues/new
# URLs to crawl: 416
# crawling https://github.com/fhswf/latex-ifv/blob/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/include/trennungen.tex#start-of-content
# URLs to crawl: 415
# crawling https://github.com/fhswf/latex-ifv/pulls#start-of-content
# URLs to crawl: 414
# crawling https://github.com/fhswf/latex-ifv/search?l=YAML&type=Wikis
# URLs to crawl: 414
# crawling https://github.com/fhswf/latex-ifv/blob/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/kapitel1.tex#start-of-content
# URLs to crawl: 413
# crawling https://github.com/fhswf/image_captioning/blob/master/score.py
# URLs to crawl: 418
# crawling https://github.com/fhswf/image_captioning/compare
# URLs to crawl: 421
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Areactions-tada-desc#start-of-content
# URLs to crawl: 420
# crawling https://github.com/fhswf/image_captioning/blob/master/captioning.ini
# URLs to crawl: 424
# crawling https://github.com/fhswf/latex-ifv/search?l=tex&type=Issues
# URLs to crawl: 424
# crawling https://github.com/fhswf/skriptsprachen/issues?q=is%3Aissue+is%3Aopen#start-of-content
# URLs to crawl: 424
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=asc&sort=title&state=open
# URLs to crawl: 424
# crawling https://github.com/fhswf/latex-ifv/find/8c0b7aaacd0eabf50253ba8400695b07212ed2b9
# URLs to crawl: 425
# crawling https://github.com/fhswf/latex-ifv/issues?q=is%3Aissue+is%3Aopen
# URLs to crawl: 426
# crawling https://github.com/fhswf/image_captioning/tree/1e6a0540401350654d7ebed1505b8b88a685be3f
# URLs to crawl: 447
# crawling https://github.com/fhswf/image_captioning/raw/b9d41fc830cf7fc3844465c03a56fda3676bf2a3/evaluation.py
# URLs to crawl: 446
# crawling https://github.com/fhswf/latex-ifv/search?l=YAML&type=Wikis#start-of-content
# URLs to crawl: 445
# crawling https://github.com/fhswf/image_captioning/blob/5cded40661b31af3f63a86124fc9086af365f088/.gitattributes
# URLs to crawl: 448
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+sort%3Acreated-desc#start-of-content
# URLs to crawl: 448
# crawling https://github.com/fhswf/image_captioning/commit/7744ee451ae256795f8d936400f450c9ffdcb3cd#diff-04d2c9518498da64bfa9db44c6211645
# URLs to crawl: 451
# crawling https://github.com/fhswf/skriptsprachen/labels?sort=count-asc
# URLs to crawl: 451
# crawling https://github.com/fhswf/latex-ifv/commits/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/kapitel1.tex
# URLs to crawl: 455
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Aupdated-desc#start-of-content
# URLs to crawl: 455
# crawling https://github.com/fhswf/image_captioning/tree/5cded40661b31af3f63a86124fc9086af365f088/images
# URLs to crawl: 460
# crawling https://github.com/fhswf/skriptsprachen/compare
# URLs to crawl: 469
# crawling https://github.com/fhswf/latex-ifv/branches/active
# URLs to crawl: 469
# crawling https://github.com/fhswf/image_captioning/archive/1e6a0540401350654d7ebed1505b8b88a685be3f.zip
# URLs to crawl: 468
# crawling https://github.com/fhswf/image_captioning/network/members
# URLs to crawl: 468
# crawling https://github.com/fhswf/latex-ifv/blob/master/README.md#start-of-content
# URLs to crawl: 467
# crawling https://github.com/fhswf/latex-ifv/stargazers
# URLs to crawl: 468
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+sort%3Aupdated-desc+is%3Aopen
# URLs to crawl: 469
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+sort%3Areactions-rocket-desc
# URLs to crawl: 471
# crawling https://github.com/fhswf/latex-ifv/blame/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/.gitlab-ci.yml
# URLs to crawl: 484
# crawling https://github.com/fhswf/latex-ifv/tree/8c0b7aaacd0eabf50253ba8400695b07212ed2b9
# URLs to crawl: 489
# crawling https://github.com/fhswf/image_captioning/blob/5cded40661b31af3f63a86124fc9086af365f088/images/encoder-decoder.png
# URLs to crawl: 491
# crawling https://github.com/fhswf/image_captioning/network
# URLs to crawl: 491
# crawling https://github.com/fhswf/skriptsprachen/labels/documentation
# URLs to crawl: 491
# crawling https://github.com/fhswf/latex-ifv/blob/master/LICENSE
# URLs to crawl: 495
# crawling https://github.com/fhswf/image_captioning/tree/d4530dfb585786be3c37b8c45524b048335b177d
# URLs to crawl: 515
# crawling https://github.com/fhswf/image_captioning/blob/1e6a0540401350654d7ebed1505b8b88a685be3f/model.py
# URLs to crawl: 518
# crawling https://github.com/fhswf/latex-ifv/blob/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/ifv.sty#start-of-content
# URLs to crawl: 517
# crawling https://github.com/fhswf/image_captioning/commits/5cded40661b31af3f63a86124fc9086af365f088
# URLs to crawl: 538
# crawling https://github.com/fhswf/image_captioning/blame/8fa3bf3d73307f96848d9bb3db1ece203ab50f21/.gitignore
# URLs to crawl: 543
# crawling https://github.com/fhswf/skriptsprachen/network/members#start-of-content
# URLs to crawl: 542
# crawling https://github.com/fhswf/image_captioning/blame/b9eaa359419ca6a559d7ed743b3ddb210c6d64ee/evaluation.py
# URLs to crawl: 546
# crawling https://github.com/fhswf/image_captioning/raw/5cded40661b31af3f63a86124fc9086af365f088/images/encoder-decoder.png
# URLs to crawl: 545
# crawling https://github.com/fhswf/latex-ifv/search?l=BibTeX&type=Issues
# URLs to crawl: 545
# crawling https://github.com/fhswf/latex-ifv/commits/master
# URLs to crawl: 577
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+comments%3A%3E50+sort%3Acreated-desc+is%3Aclosed#start-of-content
# URLs to crawl: 577
# crawling https://github.com/fhswf/latex-ifv/blob/master/lehrbrief-vorlage.pdf
# URLs to crawl: 579
# crawling https://github.com/fhswf/latex-ifv/security/policy#start-of-content
# URLs to crawl: 578
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Arequired
# URLs to crawl: 593
# crawling https://github.com/fhswf/latex-ifv/tree/44f97b3401b47e2c69e4b39fcd24802825996373
# URLs to crawl: 599
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Areactions-thinking_face-desc
# URLs to crawl: 602
# crawling https://github.com/fhswf/skriptsprachen/issues?q=is%3Apr+is%3Aopen+base%3Amaster+no%3Amilestone+no%3Alabel
# URLs to crawl: 603
# crawling https://github.com/fhswf/image_captioning/commit/a257b369950b9640c728847dbb239b8deee522e6#diff-04d2c9518498da64bfa9db44c6211645
# URLs to crawl: 607
# crawling https://github.com/fhswf/image_captioning/search?l=python
# URLs to crawl: 617
# crawling https://github.com/fhswf/skriptsprachen/pulls?q=is%3Apr+is%3Aopen
# URLs to crawl: 617
# crawling https://github.com/fhswf/image_captioning/blob/1e6a0540401350654d7ebed1505b8b88a685be3f/.gitattributes
# URLs to crawl: 620
# crawling https://github.com/fhswf/skriptsprachen/labels/help%20wanted
# URLs to crawl: 621
# crawling https://github.com/fhswf/latex-ifv/tree/d00360f067cb2fecb3d62cfd2cab79a333f6eb8c
# URLs to crawl: 630
# crawling https://github.com/fhswf/image_captioning/blob/master/evaluation.py#start-of-content
# URLs to crawl: 629
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Arequired+sort%3Acomments-asc
# URLs to crawl: 637
# crawling https://github.com/fhswf/latex-ifv/commits?author=cgawron
# URLs to crawl: 637
# crawling https://github.com/fhswf/image_captioning/commit/b79627bc44d6c302f66abb0d494bef0e8f5feca2
# URLs to crawl: 641
# crawling https://github.com/fhswf/latex-ifv/tree/d00360f067cb2fecb3d62cfd2cab79a333f6eb8c/tex
# URLs to crawl: 653
# crawling https://github.com/fhswf/latex-ifv/issues?q=is%3Aopen+no%3Alabel
# URLs to crawl: 653
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+sort%3Acreated-asc
# URLs to crawl: 660
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+sort%3Areactions-smile-desc+is%3Aopen
# URLs to crawl: 660
# crawling https://github.com/fhswf/latex-ifv/commits/master/LICENSE
# URLs to crawl: 661
# crawling https://github.com/fhswf/image_captioning/blob/d4530dfb585786be3c37b8c45524b048335b177d/README.md
# URLs to crawl: 670
# crawling https://github.com/fhswf/image_captioning/commit/b575f8f6b95745cdd9a7baa3c4b89172fb6b2ea2
# URLs to crawl: 674
# crawling https://github.com/fhswf/image_captioning/tree/5cded40661b31af3f63a86124fc9086af365f088#introduction
# URLs to crawl: 673
# crawling https://github.com/fhswf/image_captioning/archive/master.zip
# URLs to crawl: 672
# crawling https://github.com/fhswf/latex-ifv/search?l=TeX&type=Commits
# URLs to crawl: 672
# crawling https://github.com/fhswf/latex-ifv/issues?q=is%3Aopen+label%3Awontfix+no%3Aassignee
# URLs to crawl: 673
# crawling https://github.com/fhswf/latex-ifv/blame/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/include/trennungen.tex
# URLs to crawl: 673
# crawling https://github.com/fhswf/image_captioning/blob/master/rest_service.py
# URLs to crawl: 678
# crawling https://github.com/fhswf/latex-ifv/commit/c2e8c3bcd23d4fd7b3ce68363ce0d1c13457d305
# URLs to crawl: 682
# crawling https://github.com/fhswf/image_captioning/pulse/daily
# URLs to crawl: 682
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+comments%3A%3E50+is%3Aclosed+sort%3Aupdated-asc
# URLs to crawl: 685
# crawling https://github.com/fhswf/image_captioning/security/advisories?state=published#start-of-content
# URLs to crawl: 684
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+comments%3A%3E50+sort%3Areactions-rocket-desc+is%3Aclosed
# URLs to crawl: 685
# crawling https://github.com/fhswf/latex-ifv/blame/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/kapitel1.tex
# URLs to crawl: 685
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+sort%3Areactions-eyes-desc
# URLs to crawl: 688
# crawling https://github.com/fhswf/image_captioning/tree/3d7b9f61401a7a21be1af7a181a353083a10e213
# URLs to crawl: 709
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Anone
# URLs to crawl: 724
# crawling https://github.com/fhswf/image_captioning/blob/master/0_Dataset.ipynb
# URLs to crawl: 729
# crawling https://github.com/fhswf/image_captioning/blame/1e6a0540401350654d7ebed1505b8b88a685be3f/model.py
# URLs to crawl: 730
# crawling https://github.com/fhswf/latex-ifv/branches/all#start-of-content
# URLs to crawl: 729
# crawling https://github.com/fhswf/image_captioning/commits/d4530dfb585786be3c37b8c45524b048335b177d/README.md
# URLs to crawl: 730
# crawling https://github.com/fhswf/latex-ifv/tree/fdfed412bc7f79f90e35f9dd0daaddc2f714a63c
# URLs to crawl: 736
# crawling https://github.com/fhswf/image_captioning/commit/b79627bc44d6c302f66abb0d494bef0e8f5feca2?diff=split
# URLs to crawl: 737
# crawling https://github.com/fhswf/image_captioning/blame/b23442856ddbc5bae2d01d064660c469f37a3b9f/evaluation.py
# URLs to crawl: 741
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Arequired+sort%3Aupdated-asc
# URLs to crawl: 747
# crawling https://github.com/fhswf/image_captioning/pulls?q=is%3Apr+is%3Aopen+review%3Arequired+sort%3Acomments-asc#start-of-content
# URLs to crawl: 747
# crawling https://github.com/fhswf/skriptsprachen/labels/wontfix#start-of-content
# URLs to crawl: 746
# crawling https://github.com/fhswf/latex-ifv/commit/22344ea764d5d79f37375c7629b49e5869fe88e0
# URLs to crawl: 750
# crawling https://github.com/fhswf/image_captioning/commit/5cded40661b31af3f63a86124fc9086af365f088
# URLs to crawl: 752
# crawling https://github.com/fhswf/image_captioning/commit/b79627bc44d6c302f66abb0d494bef0e8f5feca2#diff-93ff136fae812392eb0f68d1ce89b7fe
# URLs to crawl: 751
# crawling https://github.com/fhswf/latex-ifv/commits/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/ifv.sty
# URLs to crawl: 755
# crawling https://github.com/fhswf/latex-ifv/tree/8c0b7aaacd0eabf50253ba8400695b07212ed2b9#installation-unter-debian-9
# URLs to crawl: 754
# crawling https://github.com/fhswf/image_captioning/commits/5cded40661b31af3f63a86124fc9086af365f088/images
# URLs to crawl: 755
# crawling https://github.com/fhswf/skriptsprachen/pulls?q=is%3Apr+is%3Aopen#start-of-content
# URLs to crawl: 755
# crawling https://github.com/fhswf/latex-ifv/search?l=TeX#start-of-content
# URLs to crawl: 754
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+comments%3A%3E50+is%3Aclosed+sort%3Acomments-desc
# URLs to crawl: 756
# crawling https://github.com/fhswf/latex-ifv/raw/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/.gitlab-ci.yml
# URLs to crawl: 755
# crawling https://github.com/fhswf/image_captioning/tree/b9eaa359419ca6a559d7ed743b3ddb210c6d64ee
# URLs to crawl: 784
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+sort%3Aupdated-asc
# URLs to crawl: 787
# crawling https://github.com/fhswf/latex-ifv/search?l=tex#start-of-content
# URLs to crawl: 786
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+sort%3Acreated-desc+updated%3A%3C2019-09-20
# URLs to crawl: 803
# crawling https://github.com/fhswf/image_captioning/blob/1e6a0540401350654d7ebed1505b8b88a685be3f/2_Training.ipynb
# URLs to crawl: 807
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+updated%3A%3C2019-09-20+sort%3Aupdated-desc
# URLs to crawl: 811
# crawling https://github.com/fhswf/skriptsprachen
# URLs to crawl: 833
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+sort%3Aupdated-desc+review%3Achanges-requested
# URLs to crawl: 849
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+updated%3A%3C2019-09-20+sort%3Areactions-smile-desc
# URLs to crawl: 851
# crawling https://github.com/fhswf/latex-ifv/commits/d00360f067cb2fecb3d62cfd2cab79a333f6eb8c/tex
# URLs to crawl: 859
# crawling https://github.com/fhswf/image_captioning/blame/1e6a0540401350654d7ebed1505b8b88a685be3f/utils.py
# URLs to crawl: 861
# crawling https://github.com/fhswf/image_captioning/blob/master/pexel.py
# URLs to crawl: 866
# crawling https://github.com/fhswf/image_captioning/tree/1e6a0540401350654d7ebed1505b8b88a685be3f#image-captioning
# URLs to crawl: 865
# crawling https://github.com/fhswf/image_captioning/blob/master/data_loader.py
# URLs to crawl: 870
# crawling https://github.com/fhswf/image_captioning/blob/d4530dfb585786be3c37b8c45524b048335b177d/README.md#data
# URLs to crawl: 869
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=desc&sort=title&state=closed
# URLs to crawl: 869
# crawling https://github.com/fhswf/latex-ifv/branches/stale
# URLs to crawl: 869
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+comments%3A%3E50+is%3Aclosed+sort%3Acomments-desc#start-of-content
# URLs to crawl: 869
# crawling https://github.com/fhswf/latex-ifv/labels/documentation
# URLs to crawl: 869
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+review%3Arequired+sort%3Aupdated-asc+is%3Aclosed
# URLs to crawl: 887
# crawling https://github.com/fhswf/image_captioning/commits/5cded40661b31af3f63a86124fc9086af365f088/images/encoder-decoder.png
# URLs to crawl: 888
# crawling https://github.com/fhswf/skriptsprachen/security/policy
# URLs to crawl: 888
# crawling https://github.com/fhswf/latex-ifv/blob/master/.gitlab-ci.yml#start-of-content
# URLs to crawl: 887
# crawling https://github.com/fhswf/image_captioning/blob/5cded40661b31af3f63a86124fc9086af365f088/1_Preliminaries.ipynb
# URLs to crawl: 891
# crawling https://github.com/fhswf/image_captioning/commit/3d7b9f61401a7a21be1af7a181a353083a10e213#start-of-content
# URLs to crawl: 890
# crawling https://github.com/fhswf/image_captioning/search?l=python#start-of-content
# URLs to crawl: 889
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Achanges-requested+sort%3Areactions-thinking_face-desc
# URLs to crawl: 897
# crawling https://github.com/fhswf/image_captioning/blame/1e6a0540401350654d7ebed1505b8b88a685be3f/.gitattributes
# URLs to crawl: 897
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+sort%3Areactions-tada-desc
# URLs to crawl: 900
# crawling https://github.com/fhswf/image_captioning/pulls?q=is%3Apr+is%3Aopen+sort%3Aupdated-desc#start-of-content
# URLs to crawl: 900
# crawling https://github.com/fhswf/image_captioning/commit/5cded40661b31af3f63a86124fc9086af365f088?diff=unified
# URLs to crawl: 901
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+updated%3A%3C2019-09-20
# URLs to crawl: 916
# crawling https://github.com/fhswf/image_captioning/blob/5cded40661b31af3f63a86124fc9086af365f088/1_Preliminaries.ipynb#start-of-content
# URLs to crawl: 915
# crawling https://github.com/fhswf/skriptsprachen/commit/524cccdfb6f0752004a17503558954244b541d68
# URLs to crawl: 921
# crawling https://github.com/fhswf/image_captioning/blame/c52d1649c0ec56bbd05c99f33ff7b389cad88733/evaluation.py
# URLs to crawl: 925
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+sort%3Aupdated-desc+review%3Aapproved
# URLs to crawl: 940
# crawling https://github.com/fhswf/image_captioning#image-captioning
# URLs to crawl: 939
# crawling https://github.com/fhswf/skriptsprachen/projects
# URLs to crawl: 939
# crawling https://github.com/fhswf/latex-ifv/issues#start-of-content
# URLs to crawl: 938
# crawling https://github.com/fhswf/skriptsprachen/compare/master...lurom001:master
# URLs to crawl: 945
# crawling https://github.com/fhswf/image_captioning/blob/d4530dfb585786be3c37b8c45524b048335b177d/README.md#start-of-content
# URLs to crawl: 944
# crawling https://github.com/fhswf/image_captioning/blob/8fa3bf3d73307f96848d9bb3db1ece203ab50f21/pexel.py
# URLs to crawl: 947
# crawling https://github.com/fhswf/image_captioning/commit/b79627bc44d6c302f66abb0d494bef0e8f5feca2?diff=unified
# URLs to crawl: 948
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=asc&sort=completeness&state=closed
# URLs to crawl: 948
# crawling https://github.com/fhswf/image_captioning/search?l=python&type=Wikis
# URLs to crawl: 948
# crawling https://github.com/fhswf/image_captioning/raw/c52d1649c0ec56bbd05c99f33ff7b389cad88733/evaluation.py
# URLs to crawl: 947
# crawling https://github.com/fhswf/image_captioning/commits/1e6a0540401350654d7ebed1505b8b88a685be3f/utils.py
# URLs to crawl: 947
# crawling https://github.com/fhswf/image_captioning/graphs/code-frequency#start-of-content
# URLs to crawl: 946
# crawling https://github.com/fhswf/latex-ifv/commits/master/lehrbrief-vorlage.pdf
# URLs to crawl: 947
# crawling https://github.com/fhswf/image_captioning/commits/1e6a0540401350654d7ebed1505b8b88a685be3f/.gitattributes
# URLs to crawl: 948
# crawling https://github.com/fhswf/latex-ifv/issues?q=is%3Aopen+no%3Alabel#start-of-content
# URLs to crawl: 948
# crawling https://github.com/fhswf/latex-ifv/search
# URLs to crawl: 953
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aclosed
# URLs to crawl: 972
# crawling https://github.com/fhswf/image_captioning/tree/master/frontend
# URLs to crawl: 977
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aopen+is%3Apr
# URLs to crawl: 995
# crawling https://github.com/fhswf/skriptsprachen/stargazers/you_know
# URLs to crawl: 994
# crawling https://github.com/fhswf/image_captioning/archive/b9eaa359419ca6a559d7ed743b3ddb210c6d64ee.zip
# URLs to crawl: 993
# crawling https://github.com/fhswf/latex-ifv/labels/enhancement
# URLs to crawl: 994
# crawling https://github.com/fhswf/latex-ifv/tree/40cf79e16f4ea43b5f52bda0f591f469ecdb79cb
# URLs to crawl: 1000
# crawling https://github.com/fhswf/image_captioning/tree/d4530dfb585786be3c37b8c45524b048335b177d#data
# URLs to crawl: 999
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+updated%3A%3C2019-09-20+sort%3Areactions-%2B1-desc
# URLs to crawl: 1002
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+sort%3Areactions-tada-desc+comments%3A%3E50+is%3Aopen
# URLs to crawl: 1017
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+comments%3A%3E50+sort%3Areactions-eyes-desc+is%3Aclosed
# URLs to crawl: 1018
# crawling https://github.com/fhswf/latex-ifv/milestones?direction=desc&sort=completeness&state=open#start-of-content
# URLs to crawl: 1017
# crawling https://github.com/fhswf/image_captioning/blame/8fa3bf3d73307f96848d9bb3db1ece203ab50f21/.gitignore#start-of-content
# URLs to crawl: 1016
# crawling https://github.com/fhswf/image_captioning/commits/master/0_Dataset.ipynb
# URLs to crawl: 1017
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+updated%3A%3C2019-09-20+sort%3Areactions-eyes-desc
# URLs to crawl: 1021
# crawling https://github.com/fhswf/latex-ifv/search?type=RegistryPackages
# URLs to crawl: 1021
# crawling https://github.com/fhswf/image_captioning/tree/d4530dfb585786be3c37b8c45524b048335b177d#run
# URLs to crawl: 1020
# crawling https://github.com/fhswf/image_captioning/find/5cded40661b31af3f63a86124fc9086af365f088
# URLs to crawl: 1021
# crawling https://github.com/fhswf/latex-ifv/tree/d3e1b88b6807c0cb55819508b097240f87ebd322
# URLs to crawl: 1030
# crawling https://github.com/fhswf/latex-ifv/tree/8c0b7aaacd0eabf50253ba8400695b07212ed2b9#start-of-content
# URLs to crawl: 1029
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aopen+is%3Apr+review%3Achanges-requested
# URLs to crawl: 1045
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+author%3Acgawron
# URLs to crawl: 1065
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+sort%3Areactions-tada-desc+comments%3A%3E50#start-of-content
# URLs to crawl: 1065
# crawling https://github.com/fhswf/latex-ifv/blob/d00360f067cb2fecb3d62cfd2cab79a333f6eb8c/lehrbrief-vorlage.pdf
# URLs to crawl: 1067
# crawling https://github.com/fhswf/skriptsprachen/tree/master/lecture_02
# URLs to crawl: 1075
# crawling https://github.com/fhswf/latex-ifv/commits/master/.gitlab-ci.yml
# URLs to crawl: 1081
# crawling https://github.com/fhswf/image_captioning#setup
# URLs to crawl: 1080
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Achanges-requested+sort%3Acreated-asc
# URLs to crawl: 1083
# crawling https://github.com/fhswf/image_captioning/pull/2
# URLs to crawl: 1093
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Arequired+sort%3Areactions-eyes-desc
# URLs to crawl: 1100
# crawling https://github.com/fhswf/latex-ifv/commit/47f14d5d8ddff5c0786fac519288d849e99843ac#diff-5df398e7946db5ded47290cbb43c5028
# URLs to crawl: 1110
# crawling https://github.com/fhswf/image_captioning/pull/2/commits
# URLs to crawl: 1112
# crawling https://github.com/fhswf/image_captioning/security/advisories#start-of-content
# URLs to crawl: 1111
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Achanges-requested+sort%3Acreated-asc+-label%3Abug
# URLs to crawl: 1131
# crawling https://github.com/fhswf/skriptsprachen/pulse/daily#start-of-content
# URLs to crawl: 1130
# crawling https://github.com/fhswf/image_captioning/blob/b9eaa359419ca6a559d7ed743b3ddb210c6d64ee/vocabulary.py
# URLs to crawl: 1133
# crawling https://github.com/fhswf/image_captioning/tree/d4530dfb585786be3c37b8c45524b048335b177d#setup
# URLs to crawl: 1132
# crawling https://github.com/fhswf/latex-ifv/search?l=tex&type=Code
# URLs to crawl: 1132
# crawling https://github.com/fhswf/image_captioning/blame/5cded40661b31af3f63a86124fc9086af365f088/utils.py
# URLs to crawl: 1134
# crawling https://github.com/fhswf/image_captioning/blob/c52d1649c0ec56bbd05c99f33ff7b389cad88733/evaluation.py
# URLs to crawl: 1135
# crawling https://github.com/fhswf/latex-ifv/commit/401aa29aaad673dff1aaa13300bce58cadcfb2fe#diff-62af5d932db7ec6b31ce36a9dd772678
# URLs to crawl: 1160
# crawling https://github.com/fhswf/image_captioning/tree/master/images
# URLs to crawl: 1166
# crawling https://github.com/fhswf/image_captioning/pulls?q=is%3Apr+is%3Aopen+sort%3Aupdated-desc+review%3Aapproved#start-of-content
# URLs to crawl: 1166
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+updated%3A%3C2019-09-20+sort%3Acreated-desc
# URLs to crawl: 1169
# crawling https://github.com/fhswf/image_captioning/raw/1e6a0540401350654d7ebed1505b8b88a685be3f/2_Training.ipynb
# URLs to crawl: 1168
# crawling https://github.com/fhswf/skriptsprachen/commit/5f36d9d1633649d6de49beee5c94515dd83dc629
# URLs to crawl: 1184
# crawling https://github.com/fhswf/latex-ifv/commit/40cf79e16f4ea43b5f52bda0f591f469ecdb79cb
# URLs to crawl: 1194
# crawling https://github.com/fhswf/image_captioning/pull/2#event-2554619736
# URLs to crawl: 1193
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+review%3Achanges-requested+sort%3Acreated-asc+is%3Aclosed
# URLs to crawl: 1211
# crawling https://github.com/fhswf/skriptsprachen/compare/master...fhswf:master
# URLs to crawl: 1218
# crawling https://github.com/fhswf/skriptsprachen/labels/duplicate
# URLs to crawl: 1219
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+author%3Acgawron+sort%3Areactions-eyes-desc
# URLs to crawl: 1227
# crawling https://github.com/fhswf/image_captioning/blob/5cded40661b31af3f63a86124fc9086af365f088/0_Dataset.ipynb
# URLs to crawl: 1231
# crawling https://github.com/fhswf/image_captioning/blob/b9eaa359419ca6a559d7ed743b3ddb210c6d64ee/rest_service.py
# URLs to crawl: 1234
# crawling https://github.com/fhswf/latex-ifv/commit/401aa29aaad673dff1aaa13300bce58cadcfb2fe
# URLs to crawl: 1233
# crawling https://github.com/fhswf/image_captioning/blob/d4530dfb585786be3c37b8c45524b048335b177d/0_Dataset.ipynb
# URLs to crawl: 1237
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+sort%3Aupdated-asc+review%3Anone
# URLs to crawl: 1241
# crawling https://github.com/fhswf/image_captioning/commits/master/.gitignore
# URLs to crawl: 1246
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+comments%3A%3E50+is%3Aopen+sort%3Acreated-desc
# URLs to crawl: 1247
# crawling https://github.com/fhswf/image_captioning/blob/3d7b9f61401a7a21be1af7a181a353083a10e213/1_Preliminaries.ipynb
# URLs to crawl: 1251
# crawling https://github.com/fhswf/image_captioning/blame/master/data_loader.py
# URLs to crawl: 1264
# crawling https://github.com/fhswf/image_captioning/blame/22a7fdeb25226e40c9063faaec9c8662571e7917/data_loader.py
# URLs to crawl: 1272
# crawling https://github.com/fhswf/latex-ifv/commit/22344ea764d5d79f37375c7629b49e5869fe88e0#start-of-content
# URLs to crawl: 1271
# crawling https://github.com/fhswf/latex-ifv/commit/fdfed412bc7f79f90e35f9dd0daaddc2f714a63c#diff-96edf7a6f008de9e928d04e1ae5e12a5
# URLs to crawl: 1273
# crawling https://github.com/fhswf/image_captioning/raw/master/1_Preliminaries.ipynb
# URLs to crawl: 1272
# crawling https://github.com/fhswf/image_captioning#introduction
# URLs to crawl: 1271
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+review%3Achanges-requested+is%3Aclosed+sort%3Areactions-smile-desc
# URLs to crawl: 1278
# crawling https://github.com/fhswf/image_captioning/security/policy#start-of-content
# URLs to crawl: 1277
# crawling https://github.com/fhswf/image_captioning/blob/master/frontend/annotate.js
# URLs to crawl: 1282
# crawling https://github.com/fhswf/skriptsprachen/network/dependents?dependent_type=REPOSITORY
# URLs to crawl: 1282
# crawling https://github.com/fhswf/image_captioning/blame/master/captioning.ini
# URLs to crawl: 1283
# crawling https://github.com/fhswf/skriptsprachen/compare/lurom001:master...fhswf:master
# URLs to crawl: 1291
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+sort%3Areactions-tada-desc
# URLs to crawl: 1298
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Anone+sort%3Areactions-tada-desc
# URLs to crawl: 1301
# crawling https://github.com/fhswf/image_captioning/blame/5cded40661b31af3f63a86124fc9086af365f088/1_Preliminaries.ipynb
# URLs to crawl: 1301
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+author%3Acgawron+sort%3Areactions-eyes-desc+review%3Anone
# URLs to crawl: 1317
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+sort%3Aupdated-desc+review%3Arequired
# URLs to crawl: 1320
# crawling https://github.com/fhswf/image_captioning#data
# URLs to crawl: 1319
# crawling https://github.com/fhswf/skriptsprachen/commit/524cccdfb6f0752004a17503558954244b541d68#diff-04c6e90faac2675aa89e2176d2eec7d8
# URLs to crawl: 1318
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aopen+is%3Apr+review%3Achanges-requested+sort%3Acomments-asc
# URLs to crawl: 1326
# crawling https://github.com/fhswf/image_captioning/commits/5cded40661b31af3f63a86124fc9086af365f088#start-of-content
# URLs to crawl: 1325
# crawling https://github.com/fhswf/latex-ifv/find/fdfed412bc7f79f90e35f9dd0daaddc2f714a63c
# URLs to crawl: 1326
# crawling https://github.com/fhswf/latex-ifv/commits/44f97b3401b47e2c69e4b39fcd24802825996373
# URLs to crawl: 1326
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Achanges-requested+-label%3Abug+sort%3Areactions-rocket-desc
# URLs to crawl: 1334
# crawling https://github.com/fhswf/image_captioning/blob/master/captioning.ini#start-of-content
# URLs to crawl: 1333
# crawling https://github.com/fhswf/image_captioning/tree/1e6a0540401350654d7ebed1505b8b88a685be3f#setup
# URLs to crawl: 1332
# crawling https://github.com/fhswf/image_captioning/blob/8fa3bf3d73307f96848d9bb3db1ece203ab50f21/frontend/annotate.js
# URLs to crawl: 1334
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen+comments%3A%3E50+updated%3A%3C2019-09-20+sort%3Areactions-%2B1-desc#start-of-content
# URLs to crawl: 1333
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+review%3Achanges-requested+sort%3Areactions-thinking_face-desc+is%3Aopen
# URLs to crawl: 1351
# crawling https://github.com/fhswf/skriptsprachen/compare/master...lurom001:master?diff=unified
# URLs to crawl: 1351
# crawling https://github.com/fhswf/latex-ifv/commit/1778a36d3e45f68f740884487b85e6397344d64d#diff-5df398e7946db5ded47290cbb43c5028
# URLs to crawl: 1357
# crawling https://github.com/fhswf/latex-ifv/search?l=tex&type=Issues#start-of-content
# URLs to crawl: 1356
# crawling https://github.com/fhswf/image_captioning/commit/5cded40661b31af3f63a86124fc9086af365f088?diff=split
# URLs to crawl: 1357
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+review%3Achanges-requested+is%3Aopen+sort%3Areactions-eyes-desc
# URLs to crawl: 1361
# crawling https://github.com/fhswf/latex-ifv/tree/d3e1b88b6807c0cb55819508b097240f87ebd322/tex
# URLs to crawl: 1373
# crawling https://github.com/fhswf/image_captioning/blame/90588b2d27770570da3b15286a1bafa8eaa6170d/data_loader.py
# URLs to crawl: 1378
# crawling https://github.com/fhswf/image_captioning/tree/pexels
# URLs to crawl: 1377
# crawling https://github.com/fhswf/image_captioning/tree/5cded40661b31af3f63a86124fc9086af365f088/images#start-of-content
# URLs to crawl: 1376
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+is%3Aopen+review%3Aapproved+sort%3Acomments-desc
# URLs to crawl: 1383
# crawling https://github.com/fhswf/image_captioning/blob/5cded40661b31af3f63a86124fc9086af365f088/images/encoder-decoder.png#start-of-content
# URLs to crawl: 1382
# crawling https://github.com/fhswf/skriptsprachen/labels/enhancement
# URLs to crawl: 1382
# crawling https://github.com/fhswf/image_captioning/commits/1e6a0540401350654d7ebed1505b8b88a685be3f/model.py
# URLs to crawl: 1382
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Apr+review%3Achanges-requested+is%3Aclosed+sort%3Areactions-rocket-desc
# URLs to crawl: 1389
# crawling https://github.com/fhswf/image_captioning/blame/22a7fdeb25226e40c9063faaec9c8662571e7917/evaluation.py
# URLs to crawl: 1392
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+is%3Aopen
# URLs to crawl: 1391
# crawling https://github.com/fhswf/latex-ifv/commit/4a2d4fceb658d78ebea3299a51647f32c124e9a4#diff-96edf7a6f008de9e928d04e1ae5e12a5
# URLs to crawl: 1394
# crawling https://github.com/fhswf/latex-ifv/blame/8c0b7aaacd0eabf50253ba8400695b07212ed2b9/tex/ifv.sty
# URLs to crawl: 1397
# crawling https://github.com/fhswf/image_captioning/issues?q=is%3Aissue+comments%3A%3E50+is%3Aopen+sort%3Areactions-eyes-desc
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-ba12c9cfdc47> in <module>
#      14     visited.add(url)
#      15
# ---> 16     resp = requests.get(url)
#      17     if not resp:
#      18         continue
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3/dist-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /usr/lib/python3/dist-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
for page in visited:
    print(f"visited: {page}")
for page in ignored:
    print(f"ignored: {page}")
# Out:
# visited: https://gitlab.com/fh-swf?sort=created_asc
# visited: https://gitlab.com/fh-swf?sort=updated_asc#content-body
# visited: https://gitlab.com/fh-swf#content-body
# visited: https://gitlab.com/fh-swf?sort=created_asc#content-body
# visited: https://gitlab.com/fh-swf?sort=name_asc#content-body
# visited: https://gitlab.com/fh-swf?sort=created_desc#content-body
# visited: https://gitlab.com/fh-swf?sort=name_desc
# visited: https://gitlab.com/fh-swf?sort=name_asc
# visited: https://gitlab.com/fh-swf
# visited: https://gitlab.com/fh-swf?sort=updated_desc
# visited: https://gitlab.com/fh-swf?sort=stars_desc#content-body
# visited: https://gitlab.com/fh-swf?sort=stars_desc
# visited: https://gitlab.com/fh-swf?sort=updated_desc#content-body
# visited: https://gitlab.com/fh-swf?sort=updated_asc
# visited: https://gitlab.com/fh-swf?sort=created_desc
# visited: https://gitlab.com/fh-swf?sort=name_desc#content-body
# ignored: https://gitlab.com/groups/fh-swf/-/shared
# ignored: https://gitlab.com/groups/fh-swf/-/activity
# ignored: https://about.gitlab.com/submit-feedback
# ignored: https://gitlab.com/groups/fh-swf/-/details
# ignored: https://gitlab.com/search?group_id=437441
# ignored: https://about.gitlab.com/getting-help/
# ignored: https://gitlab.com/groups/fh-swf/-/group_members
# ignored: https://gitlab.com/help
# ignored: https://next.gitlab.com
# ignored: https://gitlab.com/explore/groups
# ignored: https://gitlab.com/groups/fh-swf/-/archived
# ignored: https://gitlab.com/groups/fh-swf/-/milestones
# ignored: https://gitlab.com/groups/fh-swf/-/merge_requests
# ignored: https://gitlab.com/users/sign_in?redirect_to_referer=yes
# ignored: https://gitlab.com/groups/fh-swf/-/issues
# ignored: https://gitlab.com/
# ignored: https://about.gitlab.com/contributing
# ignored: https://gitlab.com/explore/snippets
# ignored: https://gitlab.com/explore
# ignored: https://gitlab.com/groups/fh-swf/-/boards
# ignored: https://next.gitlab.com/
# ignored: https://gitlab.com/groups/fh-swf/-/labels

# %%
help(links[0])
# Out:
# Help on HtmlElement in module lxml.html object:
#
# class HtmlElement(lxml.etree.ElementBase, HtmlMixin)
#  |  ElementBase(*children, attrib=None, nsmap=None, **_extra)
#  |
#  |  The public Element class.  All custom Element classes must inherit
#  |  from this one.  To create an Element, use the `Element()` factory.
#  |
#  |  BIG FAT WARNING: Subclasses *must not* override __init__ or
#  |  __new__ as it is absolutely undefined when these objects will be
#  |  created or destroyed.  All persistent state of Elements must be
#  |  stored in the underlying XML.  If you really need to initialize
#  |  the object after creation, you can implement an ``_init(self)``
#  |  method that will be called directly after object creation.
#  |
#  |  Subclasses of this class can be instantiated to create a new
#  |  Element.  By default, the tag name will be the class name and the
#  |  namespace will be empty.  You can modify this with the following
#  |  class attributes:
#  |
#  |  * TAG - the tag name, possibly containing a namespace in Clark
#  |    notation
#  |
#  |  * NAMESPACE - the default namespace URI, unless provided as part
#  |    of the TAG attribute.
#  |
#  |  * HTML - flag if the class is an HTML tag, as opposed to an XML
#  |    tag.  This only applies to un-namespaced tags and defaults to
#  |    false (i.e. XML).
#  |
#  |  * PARSER - the parser that provides the configuration for the
#  |    newly created document.  Providing an HTML parser here will
#  |    default to creating an HTML element.
#  |
#  |  In user code, the latter three are commonly inherited in class
#  |  hierarchies that implement a common namespace.
#  |
#  |  Method resolution order:
#  |      HtmlElement
#  |      lxml.etree.ElementBase
#  |      lxml.etree._Element
#  |      HtmlMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  cssselect(self, expr, translator='html')
#  |      Run the CSS expression on this element and its children,
#  |      returning a list of the results.
#  |
#  |      Equivalent to lxml.cssselect.CSSSelect(expr, translator='html')(self)
#  |      -- note that pre-compiling the expression can provide a substantial
#  |      speedup.
#  |
#  |  set(self, key, value=None)
#  |      set(self, key, value=None)
#  |
#  |      Sets an element attribute.  If no value is provided, or if the value is None,
#  |      creates a 'boolean' attribute without value, e.g. "<form novalidate></form>"
#  |      for ``form.set('novalidate')``.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from lxml.etree.ElementBase:
#  |
#  |  __init__(...)
#  |      ElementBase(*children, attrib=None, nsmap=None, **_extra)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from lxml.etree.ElementBase:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from lxml.etree._Element:
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __contains__(...)
#  |      __contains__(self, element)
#  |
#  |  __copy__(self)
#  |      __copy__(self)
#  |
#  |  __deepcopy__(self, memo)
#  |      __deepcopy__(self, memo)
#  |
#  |  __delitem__(...)
#  |      __delitem__(self, x)
#  |
#  |      Deletes the given subelement or a slice.
#  |
#  |  __getitem__(...)
#  |      Returns the subelement at the given position or the requested
#  |      slice.
#  |
#  |  __iter__(...)
#  |      __iter__(self)
#  |
#  |  __len__(...)
#  |      __len__(self)
#  |
#  |      Returns the number of subelements.
#  |
#  |  __repr__(...)
#  |      __repr__(self)
#  |
#  |  __reversed__(self)
#  |      __reversed__(self)
#  |
#  |  __setitem__(...)
#  |      __setitem__(self, x, value)
#  |
#  |      Replaces the given subelement index or slice.
#  |
#  |  addnext(self, element)
#  |      addnext(self, element)
#  |
#  |      Adds the element as a following sibling directly after this
#  |      element.
#  |
#  |      This is normally used to set a processing instruction or comment after
#  |      the root node of a document.  Note that tail text is automatically
#  |      discarded when adding at the root level.
#  |
#  |  addprevious(self, element)
#  |      addprevious(self, element)
#  |
#  |      Adds the element as a preceding sibling directly before this
#  |      element.
#  |
#  |      This is normally used to set a processing instruction or comment
#  |      before the root node of a document.  Note that tail text is
#  |      automatically discarded when adding at the root level.
#  |
#  |  append(self, element)
#  |      append(self, element)
#  |
#  |      Adds a subelement to the end of this element.
#  |
#  |  clear(self, keep_tail)
#  |      clear(self, keep_tail=False)
#  |
#  |      Resets an element.  This function removes all subelements, clears
#  |      all attributes and sets the text and tail properties to None.
#  |
#  |      Pass ``keep_tail=True`` to leave the tail text untouched.
#  |
#  |  extend(self, elements)
#  |      extend(self, elements)
#  |
#  |      Extends the current children by the elements in the iterable.
#  |
#  |  find(self, path, namespaces)
#  |      find(self, path, namespaces=None)
#  |
#  |      Finds the first matching subelement, by tag name or path.
#  |
#  |      The optional ``namespaces`` argument accepts a
#  |      prefix-to-namespace mapping that allows the usage of XPath
#  |      prefixes in the path expression.
#  |
#  |  findall(self, path, namespaces)
#  |      findall(self, path, namespaces=None)
#  |
#  |      Finds all matching subelements, by tag name or path.
#  |
#  |      The optional ``namespaces`` argument accepts a
#  |      prefix-to-namespace mapping that allows the usage of XPath
#  |      prefixes in the path expression.
#  |
#  |  findtext(self, path, default, namespaces)
#  |      findtext(self, path, default=None, namespaces=None)
#  |
#  |      Finds text for the first matching subelement, by tag name or path.
#  |
#  |      The optional ``namespaces`` argument accepts a
#  |      prefix-to-namespace mapping that allows the usage of XPath
#  |      prefixes in the path expression.
#  |
#  |  get(self, key, default)
#  |      get(self, key, default=None)
#  |
#  |      Gets an element attribute.
#  |
#  |  getchildren(self)
#  |      getchildren(self)
#  |
#  |      Returns all direct children.  The elements are returned in document
#  |      order.
#  |
#  |      :deprecated: Note that this method has been deprecated as of
#  |        ElementTree 1.3 and lxml 2.0.  New code should use
#  |        ``list(element)`` or simply iterate over elements.
#  |
#  |  getiterator(self, tag, *tags)
#  |      getiterator(self, tag=None, *tags)
#  |
#  |      Returns a sequence or iterator of all elements in the subtree in
#  |      document order (depth first pre-order), starting with this
#  |      element.
#  |
#  |      Can be restricted to find only elements with specific tags,
#  |      see `iter`.
#  |
#  |      :deprecated: Note that this method is deprecated as of
#  |        ElementTree 1.3 and lxml 2.0.  It returns an iterator in
#  |        lxml, which diverges from the original ElementTree
#  |        behaviour.  If you want an efficient iterator, use the
#  |        ``element.iter()`` method instead.  You should only use this
#  |        method in new code if you require backwards compatibility
#  |        with older versions of lxml or ElementTree.
#  |
#  |  getnext(self)
#  |      getnext(self)
#  |
#  |      Returns the following sibling of this element or None.
#  |
#  |  getparent(self)
#  |      getparent(self)
#  |
#  |      Returns the parent of this element or None for the root element.
#  |
#  |  getprevious(self)
#  |      getprevious(self)
#  |
#  |      Returns the preceding sibling of this element or None.
#  |
#  |  getroottree(self)
#  |      getroottree(self)
#  |
#  |      Return an ElementTree for the root node of the document that
#  |      contains this element.
#  |
#  |      This is the same as following element.getparent() up the tree until it
#  |      returns None (for the root element) and then build an ElementTree for
#  |      the last parent that was returned.
#  |
#  |  index(self, child, start: 'int', stop: 'int')
#  |      index(self, child, start=None, stop=None)
#  |
#  |      Find the position of the child within the parent.
#  |
#  |      This method is not part of the original ElementTree API.
#  |
#  |  insert(self, index: 'int', element)
#  |      insert(self, index, element)
#  |
#  |      Inserts a subelement at the given position in this element
#  |
#  |  items(self)
#  |      items(self)
#  |
#  |      Gets element attributes, as a sequence. The attributes are returned in
#  |      an arbitrary order.
#  |
#  |  iter(self, tag, *tags)
#  |      iter(self, tag=None, *tags)
#  |
#  |      Iterate over all elements in the subtree in document order (depth
#  |      first pre-order), starting with this element.
#  |
#  |      Can be restricted to find only elements with specific tags:
#  |      pass ``"{ns}localname"`` as tag. Either or both of ``ns`` and
#  |      ``localname`` can be ``*`` for a wildcard; ``ns`` can be empty
#  |      for no namespace. ``"localname"`` is equivalent to ``"{}localname"``
#  |      (i.e. no namespace) but ``"*"`` is ``"{*}*"`` (any or no namespace),
#  |      not ``"{}*"``.
#  |
#  |      You can also pass the Element, Comment, ProcessingInstruction and
#  |      Entity factory functions to look only for the specific element type.
#  |
#  |      Passing multiple tags (or a sequence of tags) instead of a single tag
#  |      will let the iterator return all elements matching any of these tags,
#  |      in document order.
#  |
#  |  iterancestors(self, tag, *tags)
#  |      iterancestors(self, tag=None, *tags)
#  |
#  |      Iterate over the ancestors of this element (from parent to parent).
#  |
#  |      Can be restricted to find only elements with specific tags,
#  |      see `iter`.
#  |
#  |  iterchildren(self, tag, *tags, reversed)
#  |      iterchildren(self, tag=None, *tags, reversed=False)
#  |
#  |      Iterate over the children of this element.
#  |
#  |      As opposed to using normal iteration on this element, the returned
#  |      elements can be reversed with the 'reversed' keyword and restricted
#  |      to find only elements with specific tags, see `iter`.
#  |
#  |  iterdescendants(self, tag, *tags)
#  |      iterdescendants(self, tag=None, *tags)
#  |
#  |      Iterate over the descendants of this element in document order.
#  |
#  |      As opposed to ``el.iter()``, this iterator does not yield the element
#  |      itself.  The returned elements can be restricted to find only elements
#  |      with specific tags, see `iter`.
#  |
#  |  iterfind(self, path, namespaces)
#  |      iterfind(self, path, namespaces=None)
#  |
#  |      Iterates over all matching subelements, by tag name or path.
#  |
#  |      The optional ``namespaces`` argument accepts a
#  |      prefix-to-namespace mapping that allows the usage of XPath
#  |      prefixes in the path expression.
#  |
#  |  itersiblings(self, tag, *tags, preceding)
#  |      itersiblings(self, tag=None, *tags, preceding=False)
#  |
#  |      Iterate over the following or preceding siblings of this element.
#  |
#  |      The direction is determined by the 'preceding' keyword which
#  |      defaults to False, i.e. forward iteration over the following
#  |      siblings.  When True, the iterator yields the preceding
#  |      siblings in reverse document order, i.e. starting right before
#  |      the current element and going backwards.
#  |
#  |      Can be restricted to find only elements with specific tags,
#  |      see `iter`.
#  |
#  |  itertext(self, tag, *tags, with_tail)
#  |      itertext(self, tag=None, *tags, with_tail=True)
#  |
#  |      Iterates over the text content of a subtree.
#  |
#  |      You can pass tag names to restrict text content to specific elements,
#  |      see `iter`.
#  |
#  |      You can set the ``with_tail`` keyword argument to ``False`` to skip
#  |      over tail text.
#  |
#  |  keys(self)
#  |      keys(self)
#  |
#  |      Gets a list of attribute names.  The names are returned in an
#  |      arbitrary order (just like for an ordinary Python dictionary).
#  |
#  |  makeelement(self, _tag, attrib, nsmap, **_extra)
#  |      makeelement(self, _tag, attrib=None, nsmap=None, **_extra)
#  |
#  |      Creates a new element associated with the same document.
#  |
#  |  remove(self, element)
#  |      remove(self, element)
#  |
#  |      Removes a matching subelement. Unlike the find methods, this
#  |      method compares elements based on identity, not on tag value
#  |      or contents.
#  |
#  |  replace(self, old_element, new_element)
#  |      replace(self, old_element, new_element)
#  |
#  |      Replaces a subelement with the element passed as second argument.
#  |
#  |  values(self)
#  |      values(self)
#  |
#  |      Gets element attribute values as a sequence of strings.  The
#  |      attributes are returned in an arbitrary order.
#  |
#  |  xpath(self, _path, *, namespaces, extensions, smart_strings, **_variables)
#  |      xpath(self, _path, namespaces=None, extensions=None, smart_strings=True, **_variables)
#  |
#  |      Evaluate an xpath expression using the element as context node.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from lxml.etree._Element:
#  |
#  |  attrib
#  |      Element attribute dictionary. Where possible, use get(), set(),
#  |      keys(), values() and items() to access element attributes.
#  |
#  |  base
#  |      The base URI of the Element (xml:base or HTML base URL).
#  |      None if the base URI is unknown.
#  |
#  |      Note that the value depends on the URL of the document that
#  |      holds the Element if there is no xml:base attribute on the
#  |      Element or its ancestors.
#  |
#  |      Setting this property will set an xml:base attribute on the
#  |      Element, regardless of the document type (XML or HTML).
#  |
#  |  nsmap
#  |      Namespace prefix->URI mapping known in the context of this
#  |      Element.  This includes all namespace declarations of the
#  |      parents.
#  |
#  |      Note that changing the returned dict has no effect on the Element.
#  |
#  |  prefix
#  |      Namespace prefix or None.
#  |
#  |  sourceline
#  |      Original line number as found by the parser or None if unknown.
#  |
#  |  tag
#  |      Element tag
#  |
#  |  tail
#  |      Text after this element's end tag, but before the next sibling
#  |      element's start tag. This is either a string or the value None, if
#  |      there was no text.
#  |
#  |  text
#  |      Text before the first subelement. This is either a string or
#  |      the value None, if there was no text.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from HtmlMixin:
#  |
#  |  drop_tag(self)
#  |      Remove the tag, but not its children or text.  The children and text
#  |      are merged into the parent.
#  |
#  |      Example::
#  |
#  |          >>> h = fragment_fromstring('<div>Hello <b>World!</b></div>')
#  |          >>> h.find('.//b').drop_tag()
#  |          >>> print(tostring(h, encoding='unicode'))
#  |          <div>Hello World!</div>
#  |
#  |  drop_tree(self)
#  |      Removes this element from the tree, including its children and
#  |      text.  The tail text is joined to the previous element or
#  |      parent.
#  |
#  |  find_class(self, class_name)
#  |      Find any elements with the given class name.
#  |
#  |  find_rel_links(self, rel)
#  |      Find any links like ``<a rel="{rel}">...</a>``; returns a list of elements.
#  |
#  |  get_element_by_id(self, id, *default)
#  |      Get the first element in a document with the given id.  If none is
#  |      found, return the default argument if provided or raise KeyError
#  |      otherwise.
#  |
#  |      Note that there can be more than one element with the same id,
#  |      and this isn't uncommon in HTML documents found in the wild.
#  |      Browsers return only the first match, and this function does
#  |      the same.
#  |
#  |  iterlinks(self)
#  |      Yield (element, attribute, link, pos), where attribute may be None
#  |      (indicating the link is in the text).  ``pos`` is the position
#  |      where the link occurs; often 0, but sometimes something else in
#  |      the case of links in stylesheets or style tags.
#  |
#  |      Note: <base href> is *not* taken into account in any way.  The
#  |      link you get is exactly the link in the document.
#  |
#  |      Note: multiple links inside of a single text string or
#  |      attribute value are returned in reversed order.  This makes it
#  |      possible to replace or delete them from the text string value
#  |      based on their reported text positions.  Otherwise, a
#  |      modification at one text position can change the positions of
#  |      links reported later on.
#  |
#  |  make_links_absolute(self, base_url=None, resolve_base_href=True, handle_failures=None)
#  |      Make all links in the document absolute, given the
#  |      ``base_url`` for the document (the full URL where the document
#  |      came from), or if no ``base_url`` is given, then the ``.base_url``
#  |      of the document.
#  |
#  |      If ``resolve_base_href`` is true, then any ``<base href>``
#  |      tags in the document are used *and* removed from the document.
#  |      If it is false then any such tag is ignored.
#  |
#  |      If ``handle_failures`` is None (default), a failure to process
#  |      a URL will abort the processing.  If set to 'ignore', errors
#  |      are ignored.  If set to 'discard', failing URLs will be removed.
#  |
#  |  resolve_base_href(self, handle_failures=None)
#  |      Find any ``<base href>`` tag in the document, and apply its
#  |      values to all links found in the document.  Also remove the
#  |      tag once it has been applied.
#  |
#  |      If ``handle_failures`` is None (default), a failure to process
#  |      a URL will abort the processing.  If set to 'ignore', errors
#  |      are ignored.  If set to 'discard', failing URLs will be removed.
#  |
#  |  rewrite_links(self, link_repl_func, resolve_base_href=True, base_href=None)
#  |      Rewrite all the links in the document.  For each link
#  |      ``link_repl_func(link)`` will be called, and the return value
#  |      will replace the old link.
#  |
#  |      Note that links may not be absolute (unless you first called
#  |      ``make_links_absolute()``), and may be internal (e.g.,
#  |      ``'#anchor'``).  They can also be values like
#  |      ``'mailto:email'`` or ``'javascript:expr'``.
#  |
#  |      If you give ``base_href`` then all links passed to
#  |      ``link_repl_func()`` will take that into account.
#  |
#  |      If the ``link_repl_func`` returns None, the attribute or
#  |      tag text will be removed completely.
#  |
#  |  text_content(self)
#  |      Return the text content of the tag (and the text in any children).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from HtmlMixin:
#  |
#  |  base_url
#  |      Returns the base URL, given when the page was parsed.
#  |
#  |      Use with ``urlparse.urljoin(el.base_url, href)`` to get
#  |      absolute URLs.
#  |
#  |  body
#  |      Return the <body> element.  Can be called from a child element
#  |      to get the document's head.
#  |
#  |  classes
#  |      A set-like wrapper around the 'class' attribute.
#  |
#  |  forms
#  |      Return a list of all the forms
#  |
#  |  head
#  |      Returns the <head> element.  Can be called from a child
#  |      element to get the document's head.
#  |
#  |  label
#  |      Get or set any <label> element associated with this element.

# %%
help(doc)
# Out:
# Help on HtmlElement in module lxml.html object:
#
# class HtmlElement(lxml.etree.ElementBase, HtmlMixin)
#  |  ElementBase(*children, attrib=None, nsmap=None, **_extra)
#  |
#  |  The public Element class.  All custom Element classes must inherit
#  |  from this one.  To create an Element, use the `Element()` factory.
#  |
#  |  BIG FAT WARNING: Subclasses *must not* override __init__ or
#  |  __new__ as it is absolutely undefined when these objects will be
#  |  created or destroyed.  All persistent state of Elements must be
#  |  stored in the underlying XML.  If you really need to initialize
#  |  the object after creation, you can implement an ``_init(self)``
#  |  method that will be called directly after object creation.
#  |
#  |  Subclasses of this class can be instantiated to create a new
#  |  Element.  By default, the tag name will be the class name and the
#  |  namespace will be empty.  You can modify this with the following
#  |  class attributes:
#  |
#  |  * TAG - the tag name, possibly containing a namespace in Clark
#  |    notation
#  |
#  |  * NAMESPACE - the default namespace URI, unless provided as part
#  |    of the TAG attribute.
#  |
#  |  * HTML - flag if the class is an HTML tag, as opposed to an XML
#  |    tag.  This only applies to un-namespaced tags and defaults to
#  |    false (i.e. XML).
#  |
#  |  * PARSER - the parser that provides the configuration for the
#  |    newly created document.  Providing an HTML parser here will
#  |    default to creating an HTML element.
#  |
#  |  In user code, the latter three are commonly inherited in class
#  |  hierarchies that implement a common namespace.
#  |
#  |  Method resolution order:
#  |      HtmlElement
#  |      lxml.etree.ElementBase
#  |      lxml.etree._Element
#  |      HtmlMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  cssselect(self, expr, translator='html')
#  |      Run the CSS expression on this element and its children,
#  |      returning a list of the results.
#  |
#  |      Equivalent to lxml.cssselect.CSSSelect(expr, translator='html')(self)
#  |      -- note that pre-compiling the expression can provide a substantial
#  |      speedup.
#  |
#  |  set(self, key, value=None)
#  |      set(self, key, value=None)
#  |
#  |      Sets an element attribute.  If no value is provided, or if the value is None,
#  |      creates a 'boolean' attribute without value, e.g. "<form novalidate></form>"
#  |      for ``form.set('novalidate')``.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from lxml.etree.ElementBase:
#  |
#  |  __init__(...)
#  |      ElementBase(*children, attrib=None, nsmap=None, **_extra)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from lxml.etree.ElementBase:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from lxml.etree._Element:
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __contains__(...)
#  |      __contains__(self, element)
#  |
#  |  __copy__(self)
#  |      __copy__(self)
#  |
#  |  __deepcopy__(self, memo)
#  |      __deepcopy__(self, memo)
#  |
#  |  __delitem__(...)
#  |      __delitem__(self, x)
#  |
#  |      Deletes the given subelement or a slice.
#  |
#  |  __getitem__(...)
#  |      Returns the subelement at the given position or the requested
#  |      slice.
#  |
#  |  __iter__(...)
#  |      __iter__(self)
#  |
#  |  __len__(...)
#  |      __len__(self)
#  |
#  |      Returns the number of subelements.
#  |
#  |  __repr__(...)
#  |      __repr__(self)
#  |
#  |  __reversed__(self)
#  |      __reversed__(self)
#  |
#  |  __setitem__(...)
#  |      __setitem__(self, x, value)
#  |
#  |      Replaces the given subelement index or slice.
#  |
#  |  addnext(self, element)
#  |      addnext(self, element)
#  |
#  |      Adds the element as a following sibling directly after this
#  |      element.
#  |
#  |      This is normally used to set a processing instruction or comment after
#  |      the root node of a document.  Note that tail text is automatically
#  |      discarded when adding at the root level.
#  |
#  |  addprevious(self, element)
#  |      addprevious(self, element)
#  |
#  |      Adds the element as a preceding sibling directly before this
#  |      element.
#  |
#  |      This is normally used to set a processing instruction or comment
#  |      before the root node of a document.  Note that tail text is
#  |      automatically discarded when adding at the root level.
#  |
#  |  append(self, element)
#  |      append(self, element)
#  |
#  |      Adds a subelement to the end of this element.
#  |
#  |  clear(self, keep_tail)
#  |      clear(self, keep_tail=False)
#  |
#  |      Resets an element.  This function removes all subelements, clears
#  |      all attributes and sets the text and tail properties to None.
#  |
#  |      Pass ``keep_tail=True`` to leave the tail text untouched.
#  |
#  |  extend(self, elements)
#  |      extend(self, elements)
#  |
#  |      Extends the current children by the elements in the iterable.
#  |
#  |  find(self, path, namespaces)
#  |      find(self, path, namespaces=None)
#  |
#  |      Finds the first matching subelement, by tag name or path.
#  |
#  |      The optional ``namespaces`` argument accepts a
#  |      prefix-to-namespace mapping that allows the usage of XPath
#  |      prefixes in the path expression.
#  |
#  |  findall(self, path, namespaces)
#  |      findall(self, path, namespaces=None)
#  |
#  |      Finds all matching subelements, by tag name or path.
#  |
#  |      The optional ``namespaces`` argument accepts a
#  |      prefix-to-namespace mapping that allows the usage of XPath
#  |      prefixes in the path expression.
#  |
#  |  findtext(self, path, default, namespaces)
#  |      findtext(self, path, default=None, namespaces=None)
#  |
#  |      Finds text for the first matching subelement, by tag name or path.
#  |
#  |      The optional ``namespaces`` argument accepts a
#  |      prefix-to-namespace mapping that allows the usage of XPath
#  |      prefixes in the path expression.
#  |
#  |  get(self, key, default)
#  |      get(self, key, default=None)
#  |
#  |      Gets an element attribute.
#  |
#  |  getchildren(self)
#  |      getchildren(self)
#  |
#  |      Returns all direct children.  The elements are returned in document
#  |      order.
#  |
#  |      :deprecated: Note that this method has been deprecated as of
#  |        ElementTree 1.3 and lxml 2.0.  New code should use
#  |        ``list(element)`` or simply iterate over elements.
#  |
#  |  getiterator(self, tag, *tags)
#  |      getiterator(self, tag=None, *tags)
#  |
#  |      Returns a sequence or iterator of all elements in the subtree in
#  |      document order (depth first pre-order), starting with this
#  |      element.
#  |
#  |      Can be restricted to find only elements with specific tags,
#  |      see `iter`.
#  |
#  |      :deprecated: Note that this method is deprecated as of
#  |        ElementTree 1.3 and lxml 2.0.  It returns an iterator in
#  |        lxml, which diverges from the original ElementTree
#  |        behaviour.  If you want an efficient iterator, use the
#  |        ``element.iter()`` method instead.  You should only use this
#  |        method in new code if you require backwards compatibility
#  |        with older versions of lxml or ElementTree.
#  |
#  |  getnext(self)
#  |      getnext(self)
#  |
#  |      Returns the following sibling of this element or None.
#  |
#  |  getparent(self)
#  |      getparent(self)
#  |
#  |      Returns the parent of this element or None for the root element.
#  |
#  |  getprevious(self)
#  |      getprevious(self)
#  |
#  |      Returns the preceding sibling of this element or None.
#  |
#  |  getroottree(self)
#  |      getroottree(self)
#  |
#  |      Return an ElementTree for the root node of the document that
#  |      contains this element.
#  |
#  |      This is the same as following element.getparent() up the tree until it
#  |      returns None (for the root element) and then build an ElementTree for
#  |      the last parent that was returned.
#  |
#  |  index(self, child, start: 'int', stop: 'int')
#  |      index(self, child, start=None, stop=None)
#  |
#  |      Find the position of the child within the parent.
#  |
#  |      This method is not part of the original ElementTree API.
#  |
#  |  insert(self, index: 'int', element)
#  |      insert(self, index, element)
#  |
#  |      Inserts a subelement at the given position in this element
#  |
#  |  items(self)
#  |      items(self)
#  |
#  |      Gets element attributes, as a sequence. The attributes are returned in
#  |      an arbitrary order.
#  |
#  |  iter(self, tag, *tags)
#  |      iter(self, tag=None, *tags)
#  |
#  |      Iterate over all elements in the subtree in document order (depth
#  |      first pre-order), starting with this element.
#  |
#  |      Can be restricted to find only elements with specific tags:
#  |      pass ``"{ns}localname"`` as tag. Either or both of ``ns`` and
#  |      ``localname`` can be ``*`` for a wildcard; ``ns`` can be empty
#  |      for no namespace. ``"localname"`` is equivalent to ``"{}localname"``
#  |      (i.e. no namespace) but ``"*"`` is ``"{*}*"`` (any or no namespace),
#  |      not ``"{}*"``.
#  |
#  |      You can also pass the Element, Comment, ProcessingInstruction and
#  |      Entity factory functions to look only for the specific element type.
#  |
#  |      Passing multiple tags (or a sequence of tags) instead of a single tag
#  |      will let the iterator return all elements matching any of these tags,
#  |      in document order.
#  |
#  |  iterancestors(self, tag, *tags)
#  |      iterancestors(self, tag=None, *tags)
#  |
#  |      Iterate over the ancestors of this element (from parent to parent).
#  |
#  |      Can be restricted to find only elements with specific tags,
#  |      see `iter`.
#  |
#  |  iterchildren(self, tag, *tags, reversed)
#  |      iterchildren(self, tag=None, *tags, reversed=False)
#  |
#  |      Iterate over the children of this element.
#  |
#  |      As opposed to using normal iteration on this element, the returned
#  |      elements can be reversed with the 'reversed' keyword and restricted
#  |      to find only elements with specific tags, see `iter`.
#  |
#  |  iterdescendants(self, tag, *tags)
#  |      iterdescendants(self, tag=None, *tags)
#  |
#  |      Iterate over the descendants of this element in document order.
#  |
#  |      As opposed to ``el.iter()``, this iterator does not yield the element
#  |      itself.  The returned elements can be restricted to find only elements
#  |      with specific tags, see `iter`.
#  |
#  |  iterfind(self, path, namespaces)
#  |      iterfind(self, path, namespaces=None)
#  |
#  |      Iterates over all matching subelements, by tag name or path.
#  |
#  |      The optional ``namespaces`` argument accepts a
#  |      prefix-to-namespace mapping that allows the usage of XPath
#  |      prefixes in the path expression.
#  |
#  |  itersiblings(self, tag, *tags, preceding)
#  |      itersiblings(self, tag=None, *tags, preceding=False)
#  |
#  |      Iterate over the following or preceding siblings of this element.
#  |
#  |      The direction is determined by the 'preceding' keyword which
#  |      defaults to False, i.e. forward iteration over the following
#  |      siblings.  When True, the iterator yields the preceding
#  |      siblings in reverse document order, i.e. starting right before
#  |      the current element and going backwards.
#  |
#  |      Can be restricted to find only elements with specific tags,
#  |      see `iter`.
#  |
#  |  itertext(self, tag, *tags, with_tail)
#  |      itertext(self, tag=None, *tags, with_tail=True)
#  |
#  |      Iterates over the text content of a subtree.
#  |
#  |      You can pass tag names to restrict text content to specific elements,
#  |      see `iter`.
#  |
#  |      You can set the ``with_tail`` keyword argument to ``False`` to skip
#  |      over tail text.
#  |
#  |  keys(self)
#  |      keys(self)
#  |
#  |      Gets a list of attribute names.  The names are returned in an
#  |      arbitrary order (just like for an ordinary Python dictionary).
#  |
#  |  makeelement(self, _tag, attrib, nsmap, **_extra)
#  |      makeelement(self, _tag, attrib=None, nsmap=None, **_extra)
#  |
#  |      Creates a new element associated with the same document.
#  |
#  |  remove(self, element)
#  |      remove(self, element)
#  |
#  |      Removes a matching subelement. Unlike the find methods, this
#  |      method compares elements based on identity, not on tag value
#  |      or contents.
#  |
#  |  replace(self, old_element, new_element)
#  |      replace(self, old_element, new_element)
#  |
#  |      Replaces a subelement with the element passed as second argument.
#  |
#  |  values(self)
#  |      values(self)
#  |
#  |      Gets element attribute values as a sequence of strings.  The
#  |      attributes are returned in an arbitrary order.
#  |
#  |  xpath(self, _path, *, namespaces, extensions, smart_strings, **_variables)
#  |      xpath(self, _path, namespaces=None, extensions=None, smart_strings=True, **_variables)
#  |
#  |      Evaluate an xpath expression using the element as context node.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from lxml.etree._Element:
#  |
#  |  attrib
#  |      Element attribute dictionary. Where possible, use get(), set(),
#  |      keys(), values() and items() to access element attributes.
#  |
#  |  base
#  |      The base URI of the Element (xml:base or HTML base URL).
#  |      None if the base URI is unknown.
#  |
#  |      Note that the value depends on the URL of the document that
#  |      holds the Element if there is no xml:base attribute on the
#  |      Element or its ancestors.
#  |
#  |      Setting this property will set an xml:base attribute on the
#  |      Element, regardless of the document type (XML or HTML).
#  |
#  |  nsmap
#  |      Namespace prefix->URI mapping known in the context of this
#  |      Element.  This includes all namespace declarations of the
#  |      parents.
#  |
#  |      Note that changing the returned dict has no effect on the Element.
#  |
#  |  prefix
#  |      Namespace prefix or None.
#  |
#  |  sourceline
#  |      Original line number as found by the parser or None if unknown.
#  |
#  |  tag
#  |      Element tag
#  |
#  |  tail
#  |      Text after this element's end tag, but before the next sibling
#  |      element's start tag. This is either a string or the value None, if
#  |      there was no text.
#  |
#  |  text
#  |      Text before the first subelement. This is either a string or
#  |      the value None, if there was no text.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from HtmlMixin:
#  |
#  |  drop_tag(self)
#  |      Remove the tag, but not its children or text.  The children and text
#  |      are merged into the parent.
#  |
#  |      Example::
#  |
#  |          >>> h = fragment_fromstring('<div>Hello <b>World!</b></div>')
#  |          >>> h.find('.//b').drop_tag()
#  |          >>> print(tostring(h, encoding='unicode'))
#  |          <div>Hello World!</div>
#  |
#  |  drop_tree(self)
#  |      Removes this element from the tree, including its children and
#  |      text.  The tail text is joined to the previous element or
#  |      parent.
#  |
#  |  find_class(self, class_name)
#  |      Find any elements with the given class name.
#  |
#  |  find_rel_links(self, rel)
#  |      Find any links like ``<a rel="{rel}">...</a>``; returns a list of elements.
#  |
#  |  get_element_by_id(self, id, *default)
#  |      Get the first element in a document with the given id.  If none is
#  |      found, return the default argument if provided or raise KeyError
#  |      otherwise.
#  |
#  |      Note that there can be more than one element with the same id,
#  |      and this isn't uncommon in HTML documents found in the wild.
#  |      Browsers return only the first match, and this function does
#  |      the same.
#  |
#  |  iterlinks(self)
#  |      Yield (element, attribute, link, pos), where attribute may be None
#  |      (indicating the link is in the text).  ``pos`` is the position
#  |      where the link occurs; often 0, but sometimes something else in
#  |      the case of links in stylesheets or style tags.
#  |
#  |      Note: <base href> is *not* taken into account in any way.  The
#  |      link you get is exactly the link in the document.
#  |
#  |      Note: multiple links inside of a single text string or
#  |      attribute value are returned in reversed order.  This makes it
#  |      possible to replace or delete them from the text string value
#  |      based on their reported text positions.  Otherwise, a
#  |      modification at one text position can change the positions of
#  |      links reported later on.
#  |
#  |  make_links_absolute(self, base_url=None, resolve_base_href=True, handle_failures=None)
#  |      Make all links in the document absolute, given the
#  |      ``base_url`` for the document (the full URL where the document
#  |      came from), or if no ``base_url`` is given, then the ``.base_url``
#  |      of the document.
#  |
#  |      If ``resolve_base_href`` is true, then any ``<base href>``
#  |      tags in the document are used *and* removed from the document.
#  |      If it is false then any such tag is ignored.
#  |
#  |      If ``handle_failures`` is None (default), a failure to process
#  |      a URL will abort the processing.  If set to 'ignore', errors
#  |      are ignored.  If set to 'discard', failing URLs will be removed.
#  |
#  |  resolve_base_href(self, handle_failures=None)
#  |      Find any ``<base href>`` tag in the document, and apply its
#  |      values to all links found in the document.  Also remove the
#  |      tag once it has been applied.
#  |
#  |      If ``handle_failures`` is None (default), a failure to process
#  |      a URL will abort the processing.  If set to 'ignore', errors
#  |      are ignored.  If set to 'discard', failing URLs will be removed.
#  |
#  |  rewrite_links(self, link_repl_func, resolve_base_href=True, base_href=None)
#  |      Rewrite all the links in the document.  For each link
#  |      ``link_repl_func(link)`` will be called, and the return value
#  |      will replace the old link.
#  |
#  |      Note that links may not be absolute (unless you first called
#  |      ``make_links_absolute()``), and may be internal (e.g.,
#  |      ``'#anchor'``).  They can also be values like
#  |      ``'mailto:email'`` or ``'javascript:expr'``.
#  |
#  |      If you give ``base_href`` then all links passed to
#  |      ``link_repl_func()`` will take that into account.
#  |
#  |      If the ``link_repl_func`` returns None, the attribute or
#  |      tag text will be removed completely.
#  |
#  |  text_content(self)
#  |      Return the text content of the tag (and the text in any children).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from HtmlMixin:
#  |
#  |  base_url
#  |      Returns the base URL, given when the page was parsed.
#  |
#  |      Use with ``urlparse.urljoin(el.base_url, href)`` to get
#  |      absolute URLs.
#  |
#  |  body
#  |      Return the <body> element.  Can be called from a child element
#  |      to get the document's head.
#  |
#  |  classes
#  |      A set-like wrapper around the 'class' attribute.
#  |
#  |  forms
#  |      Return a list of all the forms
#  |
#  |  head
#  |      Returns the <head> element.  Can be called from a child
#  |      element to get the document's head.
#  |
#  |  label
#  |      Get or set any <label> element associated with this element.

# %%
resp.url
# Out:
# 'https://www4.fh-swf.de/de/home/studieninteressierte/studienangebote/stg_so/esem_master/index.php'

# %%
for t in doc.itertext():
    print(t)
# Out:
#
# FH-SWF Home
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         // Definiert die Anzahl der sichtbaren Page-Rotator Elemente
#         visibleRotatorItems = 5;
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sprungmarken
#
#
# Zur Hauptnavigation springen
#
#
# Zur Subnavigation springen
#
#
# Zum Inhalt springen
#
#
#
#
# Fachhochschule Südwestfalen
#
#
#
#
#
#
#
#
# Mobile Version >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Studieninteressierte
#
#
# Das Studienangebot
#
#
# Studiengangsuche
#
#
# Gesamtübersicht
#
#
# Duales Studium / Verbundstudium
# Übersicht
# Verbundstudium
# Kooperative Modelle
# Angebote von Bildungspartnern
#
#
# Studium Flexibel
#
#
# International studieren
# Internationale Angebote
# Studierende von Partnerhochschulen
#
#
# Zusatzqualifikationen
#
#
# Auslaufende Studiengänge
#
#
# Infos und Beratung für Studieninteressierte
#
#
# Warum an der FH Südwestfalen studieren?
# Hochschulprofil
# Studistimmen
# Stromaufwärts mit Elektrotechnik
# Wir sind Maschinenbau
#
#
# Wir erklären die Hochschulwelt
# Abschlussarten
# Duales Studium
# Hochschulzugangsberechtigungen
# Hochschularten
# Studiengangsaufbau
# International studieren
#
#
# Wer kann mir helfen?
# Allgemeine Studienberatung
# Studienfachberatung
# Studierenden-Servicebüros
# Institut für Verbundstudien
# Studium und Behinderung
# Familienbüro
# Studierendenwerk/BAföG
#
#
# Termine und Veranstaltungen
# Info-Tage
# Langer Abend der Studienberatung
# Beratungstermine und Schnuppertage
#
#
# Bildungsmessen und Studienbörsen
#
#
# Finanzielles
# Beiträge und Gebühren
# BAföG
# Stipendien
# Kooperative Modelle
# Stellenbörse
# Studentenwohnheime
#
#
# FAQs
#
#
# Bewerbung und Einschreibung
#
#
# Online-Bewerbung
#
#
# Infos zum Auswahlverfahren
# Erläuterungen zum Clearingverfahren
#
#
# Ausländische Studienbewerberinnen und -bewerber
#
#
# Quereinsteigerinnen und -einsteiger (Studiengangwechsel)
#
#
# Zweithörerinnen und -hörer
#
#
# Gasthörerinnen und -hörer
#
#
# Beruflich Qualifizierte
# Beruflich Qualifizierte und fachtreue Bewerber/innen
# Zugangsprüfung
# Probestudium
#
#
# Bewerbungsfristen
#
#
# Angebote für Schülerinnen und Schüler
#
#
# Ansprechpartner für Schulen
#
#
# Bibliothek macht Schule
#
#
# Studieren probieren
# Was ist Studieren probieren?
# Angebotene Fächer
# Informationen zur Bewerbung
# Ansprechpartner
#
#
# Jugend forscht
#
#
# Labortage
#
#
# Vorträge für Schulklassen
#
#
# Mathe-Olympiade
#
#
# Veranstaltungen an den Standorten
#
#
# Angebote für Geflüchtete
#
#
#
#
# Studierende
#
#
# Rund ums Studium
#
#
# Studienorganisation
# Adressänderung
# Auslaufende Prüfungsordnungen
# Beurlaubung
# Exmatrikulation
# Formulare und Unterlagen
# Mutterschutz
# Prüfungsan- und abmeldung
# Prüfungsordnungen / Modulhandbücher
# Prüfungspläne und -zeiträume
# Rückmeldung
# Studierendenausweis
# Studienbescheinigung
# Studiengangwechsel / 2. Studiengang
# Verlaufspläne
# Vorlesungszeiten
#
#
# Finanzielles
# BAfÖG
# Stipendien
# Kooperative Modelle
# Beiträge und Gebühren
#
#
# Stellenbörse
# Stellenangebote an der FH Südwestfalen
# Externe Stellenangebote für Studierende und Absolventen
# Berufsausbildung an der Fachhochschule Südwestfalen
#
#
# Studentisches Leben
# Hochschulsport
# Studentisches Wohnen
# Studentisches Engagement
#
#
# FAQs
# A - E
# F - K
# L - R
# S - Z
#
#
# Vorlesungen und Stundenplan (VPIS)
#
#
# Lernzentren
#
#
# Studium Flexibel
#
#
# Zusatzqualifikationen
# IngenieurIn und Lehrkraft am Berufskolleg werden
# Weitere Zusatzqualifikationen
# Zertifikatsstudium
#
#
# Ansprechpartner
#
#
# Studierenden-Servicebüros
#
#
# Studienfachberatung
#
#
# Studierenden-Coaching
#
#
# Career Service
#
#
# Akademisches Auslandsamt
#
#
# Institut für Verbundstudien
#
#
# Studierendenwerk/BAföG
#
#
# Studentisches Engagement
# AStA
# Fachschaften
# Studentenverbindungen
# Studierendenparlament
# FH-Forum
#
#
# Gleichstellung
# Aufgaben
# Gleichstellungsteam
# Gesetzliche Grundlagen
# Qualifizierungs- und Fortbildungsangebote
# Familiengerechte Hochschule
# Gleichstellungsplan
# Gleichstellungskommission
#
#
# Familienbüro
# Internationale Version
#
#
# Studium und Behinderung
#
#
# Qualitätsverbesserungs-Kommission
#
#
# Termine und Aktuelles
#
#
# Fachbereiche
#
#
# Dozentinnen und Dozenten
#
#
# International studieren
#
#
# Studium im Ausland
# Allgemeine Informationen
# Studium in Europa: ERASMUS
# Förderungsmöglichkeiten
# Alle Partnerhochschulen nach Ländern
# Erfahrungsberichte
# Doppelabschlussprogramme
# Studium an weiteren Partnerhochschulen
#
#
# Praktika im Ausland
# Allgemeine Informationen
# Praktikum in Europa:ERASMUS
# Förderungsmöglichkeiten für Praktika weltweit
# Erfahrungsberichte
# Interkulturelle Vorbereitung
#
#
# Partnerhochschulen
# Partnerhochschulen nach Ländern
# Erasmus-Partner
# Kontakte zu weiteren Hochschulen
#
#
# Bibliothek
#
#
# Literatursuche
# KAI, der Online-Katalog
# DigiLink
# Fernleihe / DigiBib
# EZB
# Facheinstieg
#
#
# Benutzung
#
#
# Recherchehilfe
# Auskunft und Beratung
# Schulungen und E-Learning
# Rechercheportale
# Medienangebot
# Citavi
# Videotutorials
# Fernleihe
#
#
# Über uns
# Allgemeines
# Präsentation Standorte
# Rechtliche Grundlagen
# Kontakt
# ISBN-Vergabe
#
#
# IT-Services
#
#
# Benutzerberatung
#
#
# E-Mail
# Einrichtung von E-Mail Clients
# Webmailclient
# Mailinglisten
# Weiterführende Informationen
# Viren- und SPAM-Schutz
# Benutzerkennung / E-Mail-Adresse
# Groupware
#
#
# WLAN
# WLAN Abdeckung
# fhswf-webauth
# fhmobilWeb
# eduroam
#
#
# VPN-Zugang
# Wofür ist das gut?
# VPN-Profile
# VPN-Clients
# Lizenzvereinbarung
# Einrichtung
#
#
# PC-Pools
#
#
# Software
#  Windows 10 an der FH-SWF
# Microsoft Windows, Microsoft Office (für Mitarbeitende)
# KMS-Aktivierung
# Microsoft Office 365 (für Studierende)
# Microsoft Imagine Premium (Studierende)
# MATLAB (Campuslizenz)
# Sophos AntiVirus (Campuslizenz)
# Citavi (Campuslizenz)
# Nützliche Tools
#
#
# Services allgemein
# Benutzerkennung / E-Mail-Adresse
# Sciebo - die Campuscloud
# Drucken an der FH SWF
# Zentrale Lernplattform Moodle
# Terminplaner
# Groupware
# Zertifikate und eToken
#
#
# Mensa
#
#
# Login
#
#
#
#
# Forschung
#
#
# Forschungsfelder
#
#
# Aktuelle Forschungsprojekte
#
#
# Technologietransfer und Dienstleistungen
#
#
# Forschungstransfer-Center
#
#
# NRW.Innovationspartner
#
#
# Transfer- und Dienstleistungen
#
#
# Existenzgründung
#
#
# Forschungsförderung
#
#
# Allgemeine Informationen zur Forschungsförderung
#
#
# Aktuelle Bekanntmachungen
#
#
# Förderprogramme des Landes NRW
#
#
# Förderprogramme des Bundes
#
#
# Förderprogramme der EU
#
#
# Sonstige Fördermaßnahmen
#
#
# Datenbank für Elektronische Forschungsförderinformationen (ELFI)
#
#
# Institute
#
#
# In-Institute
# Breitbandkompetenzzentrum NRW
# Institut für Computer Science, Vision and Computational Intelligence
# Institut für Fahrzeugantriebstechnik
# Institut für Innovationen
# Institut für Green Technology & Ländliche Entwicklung
# Institut für Qualitätsentwicklung und -management
# Wissenschaftliches Zentrum Frühpädagogik
#
#
# Kooperierende Institute
# Fraunhofer-Anwendungszentrum für anorganische Leuchtstoffe
# Institut für Entsorgung und Umwelttechnik gGmbH (IFEU), Iserlohn
# Institut für Industriemanagement der Steinbeis-Stiftung, Meschede
# Institut für Instandhaltung und Korrosionsschutz gGmbH (IFINKOR)
# Institut für Umformtechnik GmbH (IFU), Lüdenscheid
# Kunststoffinstitut für die mittelständische Wirtschaft NRW GmbH (KIMW), Lüdenscheid
# Steinbeis-Transferzentrum - Institut für Breitband- und Medientechnik, Meschede
# Steinbeis-Transferzentrum für Umweltverfahrenstechnik und Wasserwirtschaft, Meschede
# Werkzeugbau-Institut Südwestfalen GmbH
#
#
# Labore der FH SWF
#
#
# Promotionskolleg der FH SWF
#
#
# Dozentinnen und Dozenten
#
#
#
#
# Über uns
#
#
# Aktuelles
#
#
# Alle Termine
#
#
# Veranstaltungen / Events
#
#
# Termine und Fristen für Studierende
# Termine zum Studienbeginn
#
#
# Wichtige  Meldungen
#
#
# Pressemitteilungen
#
#
# Stellenangebote
#
#
# Standorte
#
#
# Hagen
# Standortportrait
# Stadt & Umland
# FB Elektrotechnik und Informationstechnik
# FB Technische Betriebswirtschaft
# Mensa
# Öffnungszeiten Standort Hagen
#
#
# Iserlohn
# Standortportrait
# Stadt & Umland
# FB Informatik + Naturwissenschaften
# FB Maschinenbau
# Mensa
# Viele Lebenswege führen nach Iserlohn
# Öffnungszeiten Standort Iserlohn
#
#
# Meschede
# Standortportrait
# Stadt & Sauerland
# FB Ingenieur- und Wirtschaftswissenschaften
# Campus
# Termine und Neuigkeiten
# DozentInnen
# Öffnungszeiten Standort Meschede
#
#
# Soest
# Standortportrait
# Soest & Umgebung
# Campus
# FB Agrarwirtschaft
# FB Elektrische Energietechnik
# FB Maschinenbau-Automatisierungstechnik
# Wissenschaftliches Zentrum Frühpädagogik (WZF)
# Karrieretag Soest
# Institute
# Öffnungszeiten Standort Soest
#
#
# Lüdenscheid
# Öffnungszeiten Studienort Lüdenscheid
#
#
# Unser Profil
#
#
# Leitlinien
#
#
# Hochschulentwicklungsplan
#
#
# Der Rektor im Interview
#
#
# Bildergalerien
#
#
# Imagefilm
#
#
# Alumni-Portraits
#
#
# Veranstaltungshighlights
#
#
# Social Media
#
#
# Infos, Zahlen und Fakten
#
#
# Statistik
#
#
# Mitgliedschaften
#
#
# Ehrensenatoren
#
#
# Honorarprofessoren
#
#
# Preise
# Budde-Preis
# DAAD-Preis
# Dr. Kirchhoff-Preis
# Preis des Fördervereins Meschede
# Soester Agrarpreis
# Soester Innovationspreis
# UVWM Preise
#
#
# Partnerhochschulen
#
#
# Historie
#
#
# Pressemitteilungen
#
#
# Aktuelle Pressemitteilungen
#
#
# Pressearchiv
#
#
# Recherche
#
#
# Hochschulzeitung
#
#
# Ansprechpartner
#
#
# Fördervereine
#
#
# FH-Shop
#
#
#
#
#
#
#
#
# English
#
#
# Beschäftigte
# Ehemalige
# Wirtschaft
# Presse
# Anfahrt
# Kontakt
# International
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Suchoptionen
#
#
#
#
#  Volltext-Suche
#
#
#
#
#  Kontaktdaten
#
#
#
#
#  Pressearchiv
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Willkommen an der Fachhochschule Südwestfalen!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Next
#
# Prev
#
#
#
#
#
#
#
# Erfolgreich und praxisnah studieren an starken Standorten: Hagen, Iserlohn, Meschede, Soest und Lüdenscheid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Aktuelles & Termine
#
#
# Pressemitteilungen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Öffentliche Vorträge
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Vortragsreihe Honigbienen
#
#
# Bienenfreunde sind herzlich eingeladen zur Vortragsreihe, die in Kooperation mit dem Imkereiverein Soest am
# 18. Oktober
#  in Soest stattfindet.
# Weitere Informationen
#
#
# ›
#
#
#
#
#
#
#
#
#
#
# Offene Sprechstunde
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Allgemeine Studienberatung in Hagen
#
#
# Die allgemeine Studienberatung der Fachhochschule Südwestfalen in Hagen bietet am
# 22. Oktober
#  eine offene Sprechstunde an. Studieninteressierte können ohne Voranmeldung wichtige Fragen zur Studienwahl klären.
# Raum & Uhrzeit
#
#
# ›
#
#
#
#
#
#
#
#
#
#
# Rund ums Pferd
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Öffentliche Vortragsreihe mit Biss
#
#
# Stefanie Niggemeier spricht am
# 22. Oktober
#  in Soest zum Thema: Gebisse im Pferdemaul - Varianten und Einsatzzweck.
# Weitere Informationen
#
#
# ›
#
#
#
#
#
#
#
#
#
#
# Öffentlicher Vortrag
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wie verändern Start-ups die Unternehmenskultur?
#
#
# Antworten am
# 28. Oktober
# bei den Hagener Hochschulgesprächen. Die Gesprächsreihe mit Gästen aus Politik Wissenschaft, und Gesellschaft feiert dieses Jahr ihr dreißigstes Jubiläum.
# Zum Gespräch
#
#
# ›
#
#
#
#
#
#
#
#
#
#
# Presseinformation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Konsequent familienorientiert
#
#
# Die Vereinbarkeit von Studium, Beruf und Familie stellt für die Fachhochschule Südwestfalen eine grundlegende Voraussetzung für Chancengleichheit dar. Deshalb ist die FH jetzt Mitglied im Netzwerk „Familie in der Hochschule“.
# Zur Presseinformation
# ›
#
#
#
#
#
#
#
#
#
#
# Über uns
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Die Fachhochschule Südwestfalen im Portrait
#
#
# Die Fachhochschule Südwestfalen überzeugt mit ihren flachen Hierarchien, dem familiären Flair, dem breiten Studienangebot, ihren internationalen Kooperationen und der engen Vernetzung zur Wirtschaft
# ›
#
#
#
#
#
#
#
#
#
#
#
#
#
# Alle Veranstaltungen, Termine  und Meldungen >>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Gebisse im Pferdemaul: Varianten und Einsatzzweck
# 3. Vortrag der Seminarreihe „Rund ums Pferd“ an der FH am 22. Oktober
#
#
#
#
#
#
#
#
#
#
# Gas geben, Geld verdienen, weitermachen!
# Technische Fachbereiche der FH verabschieden 322 Absolventen
#
#
#
#
#
#
#
#
#
#
# Konsequent familienorientiert
# Fachhochschule Südwestfalen jetzt Mitglied im Netzwerk „Familie in der Hochschule“
#
#
#
#
#
#
#
#
#
#
# Raus aus der Komfortzone – ein fantastisches Gefühl
# Student Jovan Andreevski an der Sommerakademie Deutschlandstipendium
#
#
#
#
#
#
#
#
#
#
# Pferdefütterung in der Praxis
# 2. Vortrag der Seminarreihe „Rund ums Pferd“ an der FH am 15. Oktober
#
#
#
#
#
#
#
#
#
#
# Expertin für Fertigungstechnik berufen
# Prof. Dr. Susanne Cordes neu im Fachbereich Maschinenbau der Fachhochschule Südwestfalen in Iserlohn
#
#
#
#
#
#
#
#
#
#
# Semesterstart an der Fachhochschule Südwestfalen
# 400 Studienanfänger in Meschede beginnen ihr Studium zum Wintersemester 2019/20 – erstmalig auch in Wirtschaftspsychologie
#
#
#
#
#
#
#
#
#
#
# MINT-Herbstferien
# Programmieren lernen, Roboter bauen, Webseiten erstellen – Angebote des zdi Netzwerks für Schülerinnen und Schüler im Hochsauerlandkreis
#
#
#
#
#
#
#
#
#
#
# Klimaschutz aus wissenschaftlicher Sicht
# Fachhochschule Südwestfalen lädt zum öffentlichen Wissenschaftsseminar „Klimaschutz aus technischer und ökonomischer Sicht“ ein
#
#
#
#
#
#
#
#
#
#
# Kreativ um die Ecke denken ist studierbar
# Design- und Projektmanagement studieren – Infos zum Studium an der FH
#
#
#
#
#
#
#
#
#
#
# Kreative Medienarbeit beginnt in der KiTa
# Fachhochschule und Kreis Soest: Medienkompetenz nachhaltig stärken
#
#
#
#
#
#
#
#
#
#
# Aktuelle Pressemitteilungen der FH Südwestfalen
# Die Pressemitteilungen der letzten 30 Tage sowie Recherchemöglichkeiten im Archiv... >>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Direkteinstieg
#
#
#
#
#
#
#
#
#
#
#
#
# Studieninteressierte
#
#
#
#
# Studiengänge
#
#
#
#
# Bitte wählen:
#
#
#
#
# Abschluss
# Fachgebiet
# Studienform
# Voraussetzungen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Studierende
#
#
#
#
# Fachbereiche
#
#
#
#
# Bitte wählen:
#
#
#
#
# Agrarwirtschaft
# Elektrotechnik & Informationstechnik
# Elektrische Energietechnik
# Informatik & Naturwissenschaften
# Ingenieur- und Wirtschaftswissenschaften
# Maschinenbau
# Maschinenbau-Automatisierungstechnik
# Technische Betriebswirtschaft
#
#
#
#
#
#
# Bibliothek
# Datenverarbeitungszentrale
# Mensa
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Login
#
#
#
#
# Interne Server
#
#
#
#
# Bitte wählen:
#
#
#
#
# FH-Forum
# Virtuelles Service-Center
# Vorlesungsplan (VPIS)
# Bibliothek (Kai)
# Webmail
# E-learning
# Lerneinheiten Verbundstudium
# Bewerbungsportal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Meldungen & Veranstaltungen
#
#
#
#
# Aktuelles
#
#
#
#
# Bitte wählen
#
#
#
#
# Veranstaltungen und Events
# Pressemitteilungen
# Termine und Fristen
# Wichtige aktuelle Hinweise
# Stellenausschreibungen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Suche
#
#
#
#
# Suchoptionen
#
#
#
#
# Bitte wählen
#
#
#
#
# Volltext
# Kontaktdaten
# Presssemitteilungen
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Zielgruppen
#
#
#
#
# Zielgruppen
#
#
#
#
# Bitte wählen
#
#
#
#
# Studieninteressierte
# Studierende
# Beschäftigte
# International
# Forschung
# Ehemalige
# Wirtschaft
# Presse
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Zurück
#
# Nach oben
#
#
#
#
# Kontakt
# Sitemap
# Impressum
# Datenschutz
#
#
# Seite drucken
#
#
# Grauer, 1092
#
#
# Besuchen Sie uns auf Facebook
#
#
# Rss
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  var pkBaseURL = (("https:" == document.location.protocol) ? "https://download.fh-swf.de/.piwik-0950162011/piwik/" : "https://download.fh-swf.de/.piwik-0950162011/piwik/");
#  document.write(unescape("%3Cscript src='" + pkBaseURL + "piwik.js' type='text/javascript'%3E%3C/script%3E"));
#
#
#  try {
#  var piwikTracker = Piwik.getTracker(pkBaseURL + "piwik.php", 1);
#  piwikTracker.trackPageView();
#  piwikTracker.enableLinkTracking();
#  } catch( err ) {}
